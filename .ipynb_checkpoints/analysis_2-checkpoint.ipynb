# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# Imports required for ANOVA
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multicomp

import scipy
import itertools

# %%
data = pd.read_csv("final_data.csv", low_memory=False)

# %%
data.head()
# Out:
#    Unnamed: 0       eventid  iyear  imonth  iday approxdate  extended  \
# 0           0  197000000001   1970       7     2        NaN         0
# 1           1  197000000002   1970       0     0        NaN         0
# 2           2  197001000001   1970       1     0        NaN         0
# 3           3  197001000002   1970       1     0        NaN         0
# 4           4  197001000003   1970       1     0        NaN         0
#
#           country_txt                   region_txt provstate   ...   divert  \
# 0  Dominican Republic  Central America & Caribbean       NaN   ...      NaN
# 1              Mexico                North America   Federal   ...      NaN
# 2         Philippines               Southeast Asia    Tarlac   ...      NaN
# 3              Greece               Western Europe    Attica   ...      NaN
# 4               Japan                    East Asia   Fukouka   ...      NaN
#
#    kidhijcountry  ransom  ransomamt  ransomamtus  ransompaid  ransompaidus  \
# 0            NaN     0.0        NaN          NaN         NaN           NaN
# 1         Mexico     1.0   800000.0          NaN         NaN           NaN
# 2            NaN     0.0        NaN          NaN         NaN           NaN
# 3            NaN     0.0        NaN          NaN         NaN           NaN
# 4            NaN     0.0        NaN          NaN         NaN           NaN
#
#    hostkidoutcome_txt  nreleased related
# 0                 NaN        NaN     NaN
# 1                 NaN        NaN     NaN
# 2                 NaN        NaN     NaN
# 3                 NaN        NaN     NaN
# 4                 NaN        NaN     NaN
#
# [5 rows x 93 columns]

# %% [markdown]
# # Auxillary methods

# %%
# Additional function that finds all possible pairs in list
def find_pairs(values):
    return [(a, b) for a, b in itertools.permutations(values, 2)]

# %%
from functools import wraps
import errno
import os
import signal

class TimeoutError(Exception):
    pass

# Creates timeout annotation
def timeout(seconds=30, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.setitimer(signal.ITIMER_REAL,seconds) #used timer instead of alarm
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result
        return wraps(func)(wrapper)
    return decorator

# %%
# Removes rows from contingency table where some frequence is less than 5 or nan
def remove_infrequent_rows(table, treshold):
    result = table.copy(deep=True)
    for column in result.columns:
        result = result.dropna(how="any")
        #esult = result[result[column] != np.nan
        result = result[result[column] > 5]
    if (result.shape[0] / np.float64(table.shape[0])) < treshold:
        return None
    else:
        return result

# %%
def remove_infrequent_rows_with_categoricals(table, treshold):
    result = table.copy(deep=True)
    for column in result.columns:
        result = result.dropna(how="any")
        #result = result[result[column] != np.nan
        #result = result[result[column] > 5]
    if (result.shape[0] / np.float64(table.shape[0])) < treshold:
        return None
    else:
        return result

# %%
# Calculates chi square for all pairs in the list
# Input: possible_pairs -> list of tuples, containing names of possible column pairs
#        data -> pandas.DataFrame that has the columns to be analysed
#        column -> String with the name of the column, whose dependance is to be measured
# Return: void
# Result: prints all chi-square test results
def calculate_chi_square_for_column(possible_pairs, data, column, treshold):
    print("Total pairs: ", len(possible_pairs))
    for i in range(len(possible_pairs)):
        pair = possible_pairs[i]
        if column in pair:
            print("Current pair: ", i, ") ", pair)
            subset = data[[pair[0], pair[1]]]
            contingency_table = pd.crosstab(subset[pair[0]], subset[pair[1]])
            contingency_table = remove_infrequent_rows(contingency_table, treshold)
            
            # Does not calculate chi-square if the ammount of removed rows is greater than 40%
            if not isinstance(contingency_table, pd.DataFrame):
                print("Insufficient data for analysis")
                continue
            if contingency_table.empty:
                print("Insufficient data for analysis")
                continue
            print()
            print(contingency_table)
            chi = scipy.stats.chi2_contingency(contingency_table)
            print(chi)
            print()

# %%
# Performs a one-way ANOVA test to find whether the values in two columns are independent or not
def perform_anova_for_column(possible_pairs, data, column, treshold):
    print("Total pairs: ", len(possible_pairs))
    for i in range(len(possible_pairs)):
        pair = possible_pairs[i]
        if column in pair:
            print("Current pair: ", i, ") ", pair)
            subset = data[[pair[0], pair[1]]]
            subset = remove_infrequent_rows_with_categoricals(subset, treshold)
            
            if not isinstance(subset, pd.DataFrame):
                print("Insufficient data for analysis")
                continue
            if subset.empty:
                print("Insufficient data for analysis")
                continue
            print()
            formula = (str(pair[0] + "~" + str(pair[1])))
            model = smf.ols(formula=formula, data=subset)
            results = model.fit()
            
            message = ""
            @timeout(90)
            def print_results(results):
                try:
                    if results.fvalue > 50 and results.f_pvalue < 0.05 and results.f_pvalue != 0:
                        return results.summary()
                    else:
                        return "The F-statistic and p-value are too low"
                except:
                    try:
                        subset = subset.astype("category")
                        model = smf.ols(formula=formula, data=subset)
                        results = model.fit()
                        if results.fvalue > 30 and results.f_pvalue < 0.05 and results.f_pvalue != 0:
                            return results.summary()
                        else:
                            return "The F-statistic and p-value are too low"
                    except:
                        return "Could not calculate ANOVA results"
            
            message = print_results(results)
            if message == "":
                print("Calculations took too much time")
            else:
                print(message)
            print()

# %% [markdown]
# # More data preparation

# %%
# Function that turns attack type to more beautiful str
def beautify_attacktype(s):
    def remove_commas(s):
        while s.endswith(", "):
            s = s[:-2]
        return s
    parts = s.split(",")
    result = ""
    for part in parts:
        if "nan" not in part.strip():
            result += part.strip() + ", "
    
    return remove_commas(result)

# %%
# Creates new column by combining three attactype_txt columns and adds it to the dataset as attcktype_txt
new_column = pd.Series(data.attacktype1_txt.astype(str) + ', ' +  data.attacktype2_txt.astype(str) + ', ' + data.attacktype3_txt.astype(str))
data = data.assign(attacktype_txt=new_column.values)
data.attacktype_txt = data.attacktype_txt.apply(beautify_attacktype)

# Encodes attacktype_txt to category type
data.attacktype_txt = data.attacktype_txt.astype("category")
data.attacktype_txt.value_counts().head()
# Out:
# Bombing/Explosion                 86079
# Armed Assault                     40927
# Assassination                     19190
# Facility/Infrastructure Attack    10168
# Hostage Taking (Kidnapping)        9423
# Name: attacktype_txt, dtype: int64

# %% [markdown]
# # Divide data into two parts: before and after 1997

# %%
data_old = data[data.iyear < 1997].copy(deep=True)

# %%
data_old.describe()
# Out:
#          Unnamed: 0       eventid         iyear        imonth          iday  \
# count  64310.000000  6.431000e+04  64310.000000  64310.000000  64310.000000
# mean   32154.500000  1.986419e+11   1986.353180      6.457176     15.401773
# std    18564.842243  6.229994e+08      6.229454      3.398759      8.801756
# min        0.000000  1.970000e+11   1970.000000      0.000000      0.000000
# 25%    16077.250000  1.982043e+11   1982.000000      4.000000      8.000000
# 50%    32154.500000  1.987092e+11   1987.000000      6.000000     15.000000
# 75%    48231.750000  1.991093e+11   1991.000000      9.000000     23.000000
# max    64309.000000  1.996123e+11   1996.000000     12.000000     31.000000
#
#            extended      latitude     longitude   specificity      vicinity  \
# count  64310.000000  60889.000000  6.088800e+04  64310.000000  64310.000000
# mean       0.018364     18.017570 -1.429308e+03      1.429498      0.038097
# std        0.134265     24.561747  3.492772e+05      1.107537      0.191431
# min        0.000000    -53.154613 -8.618590e+07      1.000000      0.000000
# 25%        0.000000      5.222845 -7.587190e+01      1.000000      0.000000
# 50%        0.000000     14.866667 -5.661926e+00      1.000000      0.000000
# 75%        0.000000     38.388443  3.471268e+01      1.000000      0.000000
# max        1.000000     64.837778  1.784419e+02      5.000000      1.000000
#
#           ...           nhostkid   nhostkidus       nhours        ndays  \
# count     ...        3879.000000  3877.000000  1312.000000  1042.000000
# mean      ...           2.717711     0.078153     0.837652    28.729367
# std       ...         351.835431     3.787483     3.993611   129.837568
# min       ...         -99.000000   -99.000000     0.000000     0.000000
# 25%       ...           1.000000     0.000000     0.000000     1.000000
# 50%       ...           1.000000     0.000000     0.000000     3.000000
# 75%       ...           3.000000     0.000000     0.000000    12.000000
# max       ...       17000.000000    70.000000    72.000000  2454.000000
#
#              ransom     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  63936.000000  6.290000e+02          1.0  1.540000e+02      4.000000
# mean       0.010088  3.492041e+06      20000.0  1.325981e+06  16581.250000
# std        0.099933  4.066911e+07          NaN  4.715787e+06  19943.705931
# min        0.000000  0.000000e+00      20000.0  0.000000e+00      0.000000
# 25%        0.000000  0.000000e+00      20000.0  0.000000e+00      0.000000
# 50%        0.000000  1.250000e+04      20000.0  3.585000e+04  13162.500000
# 75%        0.000000  5.000000e+05      20000.0  4.770000e+05  29743.750000
# max        1.000000  1.000000e+09      20000.0  4.100000e+07  40000.000000
#
#          nreleased
# count  1186.000000
# mean      7.468803
# std      35.285447
# min     -99.000000
# 25%       1.000000
# 50%       1.000000
# 75%       3.000000
# max     390.000000
#
# [8 rows x 46 columns]

# %%
data_new = data[data.iyear >= 1997].copy(deep=True)

# %%
data_new.describe()
# Out:
#           Unnamed: 0       eventid          iyear         imonth  \
# count  117381.000000  1.173810e+05  117381.000000  117381.000000
# mean   123000.000000  2.011628e+11    2011.561573       6.472811
# std     33885.120311  5.093657e+08       5.094114       3.382563
# min     64310.000000  1.997010e+11    1997.000000       1.000000
# 25%     93655.000000  2.009092e+11    2009.000000       4.000000
# 50%    123000.000000  2.013110e+11    2013.000000       6.000000
# 75%    152345.000000  2.015083e+11    2015.000000       9.000000
# max    181690.000000  2.017123e+11    2017.000000      12.000000
#
#                 iday       extended       latitude      longitude  \
# count  117381.000000  117381.000000  116246.000000  116246.000000
# mean       15.562553       0.060129      26.369141      49.697266
# std         8.820289       0.237727      13.618503      38.354840
# min         0.000000       0.000000     -42.884049    -124.224996
# 25%         8.000000       0.000000      15.325443      36.821107
# 50%        15.000000       0.000000      32.469238      44.621403
# 75%        23.000000       0.000000      34.346722      70.759615
# max        31.000000       1.000000      74.633553     179.366667
#
#          specificity       vicinity     ...          nhostkid   nhostkidus  \
# count  117375.000000  117346.000000     ...       9693.000000  9640.000000
# mean        1.463480       0.087553     ...          5.259775    -0.527801
# std         0.928067       0.282645     ...         88.213023     7.723114
# min         1.000000       0.000000     ...        -99.000000   -99.000000
# 25%         1.000000       0.000000     ...          1.000000     0.000000
# 50%         1.000000       0.000000     ...          2.000000     0.000000
# 75%         1.000000       0.000000     ...          5.000000     0.000000
# max         5.000000       1.000000     ...       5350.000000    86.000000
#
#            nhours        ndays        ransom     ransomamt   ransomamtus  \
# count  609.000000  2827.000000  12047.000000  6.730000e+02  5.620000e+02
# mean     3.739327    44.975593      0.054287  3.100187e+06  5.794803e+05
# std      5.282431   148.237273      0.226593  1.690471e+07  7.084190e+06
# min      0.000000     0.000000      0.000000 -9.900000e+01 -9.900000e+01
# 25%      1.000000     2.000000      0.000000 -9.900000e+01  0.000000e+00
# 50%      2.000000     5.000000      0.000000  2.439603e+04  0.000000e+00
# 75%      4.000000    21.000000      0.000000  3.087375e+05  0.000000e+00
# max     24.000000  2078.000000      1.000000  2.000000e+08  1.320000e+08
#
#          ransompaid  ransompaidus    nreleased
# count  6.200000e+02    548.000000  9214.000000
# mean   5.669151e+05    121.102190   -33.714782
# std    1.108547e+07   2136.396177    67.242528
# min   -9.900000e+01    -99.000000   -99.000000
# 25%   -9.900000e+01      0.000000   -99.000000
# 50%   -9.900000e+01      0.000000     0.000000
# 75%    0.000000e+00      0.000000     1.000000
# max    2.750000e+08  48000.000000  2769.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# # Identifying important correlations for the attack types

# %% [markdown]
# ### First attack type

# %%
data.attacktype1_txt.value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
data.attacktype1_txt.value_counts().plot(kind="bar")

# %% [markdown]
# ### Second attack type

# %%
data.attacktype2_txt.value_counts()
# Out:
# Armed Assault                          3434
# Facility/Infrastructure Attack         1653
# Bombing/Explosion                       506
# Hostage Taking (Kidnapping)             479
# Assassination                           162
# Hostage Taking (Barricade Incident)      37
# Unarmed Assault                          30
# Hijacking                                10
# Unknown                                   3
# Name: attacktype2_txt, dtype: int64

# %%
data.attacktype2_txt.value_counts().plot(kind="bar")

# %% [markdown]
# ### Third attack type

# %%
data.attacktype3_txt.value_counts()
# Out:
# Facility/Infrastructure Attack         229
# Armed Assault                          119
# Hostage Taking (Kidnapping)             53
# Bombing/Explosion                       16
# Assassination                            4
# Hijacking                                4
# Hostage Taking (Barricade Incident)      2
# Unarmed Assault                          1
# Name: attacktype3_txt, dtype: int64

# %%
data.attacktype3_txt.value_counts().plot(kind="bar")

# %% [markdown]
# ## Combined attacktypes

# %%
data.attacktype_txt.value_counts()
# Out:
# Bombing/Explosion                                                                     86079
# Armed Assault                                                                         40927
# Assassination                                                                         19190
# Facility/Infrastructure Attack                                                        10168
# Hostage Taking (Kidnapping)                                                            9423
# Unknown                                                                                7276
# Bombing/Explosion, Armed Assault                                                       1782
# Hostage Taking (Kidnapping), Armed Assault                                             1217
# Armed Assault, Facility/Infrastructure Attack                                          1048
# Unarmed Assault                                                                         953
# Hostage Taking (Barricade Incident)                                                     765
# Hijacking                                                                               589
# Armed Assault, Hostage Taking (Kidnapping)                                              287
# Armed Assault, Bombing/Explosion                                                        242
# Hostage Taking (Kidnapping), Facility/Infrastructure Attack                             224
# Bombing/Explosion, Facility/Infrastructure Attack                                       164
# Hostage Taking (Kidnapping), Armed Assault, Facility/Infrastructure Attack              110
# Facility/Infrastructure Attack, Armed Assault                                           108
# Hostage Taking (Barricade Incident), Facility/Infrastructure Attack                      89
# Armed Assault, Assassination                                                             80
# Bombing/Explosion, Armed Assault, Facility/Infrastructure Attack                         77
# Hostage Taking (Kidnapping), Bombing/Explosion                                           68
# Assassination, Hostage Taking (Kidnapping)                                               67
# Bombing/Explosion, Assassination                                                         64
# Hostage Taking (Barricade Incident), Armed Assault                                       62
# Unarmed Assault, Facility/Infrastructure Attack                                          60
# Hostage Taking (Kidnapping), Bombing/Explosion, Armed Assault                            42
# Facility/Infrastructure Attack, Hostage Taking (Kidnapping)                              41
# Hostage Taking (Barricade Incident), Bombing/Explosion                                   38
# Bombing/Explosion, Hostage Taking (Kidnapping)                                           34
#                                                                                       ...
# Armed Assault, Hostage Taking (Barricade Incident), Assassination                         1
# Armed Assault, Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)           1
# Armed Assault, Facility/Infrastructure Attack, Facility/Infrastructure Attack             1
# Armed Assault, Bombing/Explosion, Hostage Taking (Barricade Incident)                     1
# Armed Assault, Bombing/Explosion, Bombing/Explosion                                       1
# Armed Assault, Bombing/Explosion, Assassination                                           1
# Hostage Taking (Kidnapping), Hostage Taking (Barricade Incident), Armed Assault           1
# Bombing/Explosion, Armed Assault, Assassination                                           1
# Hostage Taking (Kidnapping), Bombing/Explosion, Hostage Taking (Kidnapping)               1
# Assassination, Hostage Taking (Kidnapping), Hijacking                                     1
# Hijacking, Facility/Infrastructure Attack, Hostage Taking (Kidnapping)                    1
# Hijacking, Armed Assault, Hostage Taking (Kidnapping)                                     1
# Hostage Taking (Barricade Incident), Bombing/Explosion, Unarmed Assault                   1
# Facility/Infrastructure Attack, Hostage Taking (Kidnapping), Bombing/Explosion            1
# Hostage Taking (Barricade Incident), Facility/Infrastructure Attack, Armed Assault        1
# Facility/Infrastructure Attack, Bombing/Explosion, Hostage Taking (Kidnapping)            1
# Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)                          1
# Facility/Infrastructure Attack, Armed Assault, Armed Assault                              1
# Unarmed Assault, Hijacking, Facility/Infrastructure Attack                                1
# Hostage Taking (Barricade Incident), Unarmed Assault                                      1
# Bombing/Explosion, Unknown                                                                1
# Bombing/Explosion, Hostage Taking (Kidnapping), Hijacking                                 1
# Bombing/Explosion, Hijacking, Hostage Taking (Kidnapping)                                 1
# Hostage Taking (Kidnapping), Armed Assault, Assassination                                 1
# Bombing/Explosion, Armed Assault, Hostage Taking (Barricade Incident)                     1
# Hostage Taking (Kidnapping), Armed Assault, Hostage Taking (Kidnapping)                   1
# Hijacking, Hostage Taking (Barricade Incident), Armed Assault                             1
# Bombing/Explosion, Armed Assault, Armed Assault                                           1
# Unarmed Assault, Bombing/Explosion, Facility/Infrastructure Attack                        1
# Hostage Taking (Kidnapping), Unarmed Assault, Facility/Infrastructure Attack              1
# Name: attacktype_txt, Length: 113, dtype: int64

# %% [markdown]
# As attacktypes are categorical values, I am going to make two separate types of analysis to find correlations between data. The first on is a chi-squared test and it would be used to calculate differences in distribution of values between categorical values. The second one is ANOVA test and it is used to find correlation between numerical and categorical values.

# %% [markdown]
# ### Chi-square test
#
# https://en.wikipedia.org/wiki/Chi-squared_test

# %%
# Lists all categorical columns
cols = data.columns
num_cols = data._get_numeric_data().columns
cat_cols =  list(set(cols) - set(num_cols))
print(cat_cols)
# Out:
# ['motive_y', 'gsubname_x', 'natlty3_txt_x', 'attacktype3_txt', 'natlty2_txt', 'provstate', 'divert', 'corp3_x', 'approxdate', 'attacktype_txt', 'gname2_y', 'gname_y', 'gname2_x', 'target1', 'targtype3_txt_x', 'targtype1_txt', 'gsubname_y', 'natlty3_txt_y', 'motive_x', 'claimmode2_txt', 'target2', 'corp1', 'weapsubtype1_txt', 'attacktype1_txt', 'claimmode3_txt', 'city', 'gsubname2_y', 'gname3_y', 'weaptype2_txt', 'targsubtype3_txt_y', 'gname_x', 'target3_x', 'hostkidoutcome_txt', 'gsubname3_x', 'weaptype4_txt', 'weapsubtype4_txt', 'attacktype2_txt', 'propextent_txt', 'kidhijcountry', 'targsubtype2_txt', 'target3_y', 'targsubtype3_txt_x', 'weapsubtype2_txt', 'claimmode_txt', 'related', 'gname3_x', 'country_txt', 'weapsubtype3_txt', 'targtype3_txt_y', 'gsubname3_y', 'natlty1_txt', 'corp2', 'gsubname2_x', 'alternative_txt', 'corp3_y', 'targsubtype1_txt', 'weaptype1_txt', 'weaptype3_txt', 'region_txt', 'targtype2_txt']

# %% [markdown]
# #### Before 1997

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_old = data_old[cat_cols].copy(deep=True)
data_for_analysis_old.head()
# Out:
#   motive_y gsubname_x natlty3_txt_x attacktype3_txt natlty2_txt provstate  \
# 0      NaN        NaN           NaN             NaN         NaN       NaN
# 1      NaN        NaN           NaN             NaN         NaN   Federal
# 2      NaN        NaN           NaN             NaN         NaN    Tarlac
# 3      NaN        NaN           NaN             NaN         NaN    Attica
# 4      NaN        NaN           NaN             NaN         NaN   Fukouka
#
#   divert corp3_x approxdate                  attacktype_txt      ...       \
# 0    NaN     NaN        NaN                   Assassination      ...
# 1    NaN     NaN        NaN     Hostage Taking (Kidnapping)      ...
# 2    NaN     NaN        NaN                   Assassination      ...
# 3    NaN     NaN        NaN               Bombing/Explosion      ...
# 4    NaN     NaN        NaN  Facility/Infrastructure Attack      ...
#
#           natlty1_txt corp2 gsubname2_x alternative_txt corp3_y  \
# 0  Dominican Republic   NaN         NaN             NaN     NaN
# 1             Belgium   NaN         NaN             NaN     NaN
# 2       United States   NaN         NaN             NaN     NaN
# 3       United States   NaN         NaN             NaN     NaN
# 4       United States   NaN         NaN             NaN     NaN
#
#                                     targsubtype1_txt weaptype1_txt  \
# 0                                     Named Civilian       Unknown
# 1  Diplomatic Personnel (outside of embassy, cons...       Unknown
# 2                    Radio Journalist/Staff/Facility       Unknown
# 3                                  Embassy/Consulate    Explosives
# 4                                  Embassy/Consulate    Incendiary
#
#   weaptype3_txt                   region_txt targtype2_txt
# 0           NaN  Central America & Caribbean           NaN
# 1           NaN                North America           NaN
# 2           NaN               Southeast Asia           NaN
# 3           NaN               Western Europe           NaN
# 4           NaN                    East Asia           NaN
#
# [5 rows x 60 columns]

# %%
# Removes individual attacktype_txt columns
del data_for_analysis_old["attacktype1_txt"]
del data_for_analysis_old["attacktype2_txt"]
del data_for_analysis_old["attacktype3_txt"]

# %%
# Finds all possible categorical column pairs
cols = data_for_analysis_old.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('motive_y', 'gsubname_x'), ('motive_y', 'natlty3_txt_x'), ('motive_y', 'natlty2_txt'), ('motive_y', 'provstate'), ('motive_y', 'divert'), ('motive_y', 'corp3_x'), ('motive_y', 'approxdate'), ('motive_y', 'attacktype_txt'), ('motive_y', 'gname2_y'), ('motive_y', 'gname_y'), ('motive_y', 'gname2_x'), ('motive_y', 'target1'), ('motive_y', 'targtype3_txt_x'), ('motive_y', 'targtype1_txt'), ('motive_y', 'gsubname_y'), ('motive_y', 'natlty3_txt_y'), ('motive_y', 'motive_x'), ('motive_y', 'claimmode2_txt'), ('motive_y', 'target2'), ('motive_y', 'corp1'), ('motive_y', 'weapsubtype1_txt'), ('motive_y', 'claimmode3_txt'), ('motive_y', 'city'), ('motive_y', 'gsubname2_y'), ('motive_y', 'gname3_y'), ('motive_y', 'weaptype2_txt'), ('motive_y', 'targsubtype3_txt_y'), ('motive_y', 'gname_x'), ('motive_y', 'target3_x'), ('motive_y', 'hostkidoutcome_txt'), ('motive_y', 'gsubname3_x'), ('motive_y', 'weaptype4_txt'), ('motive_y', 'weapsubtype4_txt'), ('motive_y', 'propextent_txt'), ('motive_y', 'kidhijcountry'), ('motive_y', 'targsubtype2_txt'), ('motive_y', 'target3_y'), ('motive_y', 'targsubtype3_txt_x'), ('motive_y', 'weapsubtype2_txt'), ('motive_y', 'claimmode_txt'), ('motive_y', 'related'), ('motive_y', 'gname3_x'), ('motive_y', 'country_txt'), ('motive_y', 'weapsubtype3_txt'), ('motive_y', 'targtype3_txt_y'), ('motive_y', 'gsubname3_y'), ('motive_y', 'natlty1_txt'), ('motive_y', 'corp2'), ('motive_y', 'gsubname2_x'), ('motive_y', 'alternative_txt'), ('motive_y', 'corp3_y'), ('motive_y', 'targsubtype1_txt'), ('motive_y', 'weaptype1_txt'), ('motive_y', 'weaptype3_txt'), ('motive_y', 'region_txt'), ('motive_y', 'targtype2_txt'), ('gsubname_x', 'motive_y'), ('gsubname_x', 'natlty3_txt_x'), ('gsubname_x', 'natlty2_txt'), ('gsubname_x', 'provstate'), ('gsubname_x', 'divert'), ('gsubname_x', 'corp3_x'), ('gsubname_x', 'approxdate'), ('gsubname_x', 'attacktype_txt'), ('gsubname_x', 'gname2_y'), ('gsubname_x', 'gname_y'), ('gsubname_x', 'gname2_x'), ('gsubname_x', 'target1'), ('gsubname_x', 'targtype3_txt_x'), ('gsubname_x', 'targtype1_txt'), ('gsubname_x', 'gsubname_y'), ('gsubname_x', 'natlty3_txt_y'), ('gsubname_x', 'motive_x'), ('gsubname_x', 'claimmode2_txt'), ('gsubname_x', 'target2'), ('gsubname_x', 'corp1'), ('gsubname_x', 'weapsubtype1_txt'), ('gsubname_x', 'claimmode3_txt'), ('gsubname_x', 'city'), ('gsubname_x', 'gsubname2_y'), ('gsubname_x', 'gname3_y'), ('gsubname_x', 'weaptype2_txt'), ('gsubname_x', 'targsubtype3_txt_y'), ('gsubname_x', 'gname_x'), ('gsubname_x', 'target3_x'), ('gsubname_x', 'hostkidoutcome_txt'), ('gsubname_x', 'gsubname3_x'), ('gsubname_x', 'weaptype4_txt'), ('gsubname_x', 'weapsubtype4_txt'), ('gsubname_x', 'propextent_txt'), ('gsubname_x', 'kidhijcountry'), ('gsubname_x', 'targsubtype2_txt'), ('gsubname_x', 'target3_y'), ('gsubname_x', 'targsubtype3_txt_x'), ('gsubname_x', 'weapsubtype2_txt'), ('gsubname_x', 'claimmode_txt'), ('gsubname_x', 'related'), ('gsubname_x', 'gname3_x'), ('gsubname_x', 'country_txt'), ('gsubname_x', 'weapsubtype3_txt'), ('gsubname_x', 'targtype3_txt_y'), ('gsubname_x', 'gsubname3_y'), ('gsubname_x', 'natlty1_txt'), ('gsubname_x', 'corp2'), ('gsubname_x', 'gsubname2_x'), ('gsubname_x', 'alternative_txt'), ('gsubname_x', 'corp3_y'), ('gsubname_x', 'targsubtype1_txt'), ('gsubname_x', 'weaptype1_txt'), ('gsubname_x', 'weaptype3_txt'), ('gsubname_x', 'region_txt'), ('gsubname_x', 'targtype2_txt'), ('natlty3_txt_x', 'motive_y'), ('natlty3_txt_x', 'gsubname_x'), ('natlty3_txt_x', 'natlty2_txt'), ('natlty3_txt_x', 'provstate'), ('natlty3_txt_x', 'divert'), ('natlty3_txt_x', 'corp3_x'), ('natlty3_txt_x', 'approxdate'), ('natlty3_txt_x', 'attacktype_txt'), ('natlty3_txt_x', 'gname2_y'), ('natlty3_txt_x', 'gname_y'), ('natlty3_txt_x', 'gname2_x'), ('natlty3_txt_x', 'target1'), ('natlty3_txt_x', 'targtype3_txt_x'), ('natlty3_txt_x', 'targtype1_txt'), ('natlty3_txt_x', 'gsubname_y'), ('natlty3_txt_x', 'natlty3_txt_y'), ('natlty3_txt_x', 'motive_x'), ('natlty3_txt_x', 'claimmode2_txt'), ('natlty3_txt ...

# %%
calculate_chi_square_for_column(column_pairs, data_for_analysis_old, "attacktype_txt", 0.45)
# Out:
# Total pairs:  2070
# Current pair:  44 )  ('eventid', 'attacktype_txt')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-2ecebdf9346e> in <module>
# ----> 1 calculate_chi_square_for_column(column_pairs, data_for_analysis_old, "attacktype_txt", 0.45)
#
# <ipython-input-7-b431674eb71c> in calculate_chi_square_for_column(possible_pairs, data, column, treshold)
#      11         if column in pair:
#      12             print("Current pair: ", i, ") ", pair)
# ---> 13             subset = data[[pair[0], pair[1]]]
#      14             contingency_table = pd.crosstab(subset[pair[0]], subset[pair[1]])
#      15             contingency_table = remove_infrequent_rows(contingency_table, tres)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['eventid' 'attacktype_txt'] not in index"

# %%
# Controlls one pair that showed results
calculate_chi_square_for_column([("claimmode3_txt", "attacktype_txt")], data_for_analysis_old, "attacktype_txt", 0.45)
# Out:
# Total pairs:  1
# Current pair:  0 )  ('claimmode3_txt', 'attacktype_txt')
#
# attacktype_txt  Bombing/Explosion
# claimmode3_txt
# Other                           7
# (0.0, 1.0, 0, array([[7.]]))

# %% [markdown]
# The only pair that gave the results consists of empty table and therefore the result is false. The conducted test shows that **there is no dependance between categorical values in the data before the year 1997**. One of the possible reasons lies in fact, that many statistics were collected only from year 1997.

# %% [markdown]
# #### After 1997

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_new = data_new[cat_cols].copy(deep=True)
data_for_analysis_new.head()
# Out:
#       motive_y gsubname_x natlty3_txt_x attacktype3_txt natlty2_txt  \
# 64310      NaN        NaN           NaN             NaN         NaN
# 64311      NaN   Settlers           NaN             NaN         NaN
# 64312      NaN        NaN           NaN             NaN         NaN
# 64313      NaN        NaN           NaN             NaN         NaN
# 64314      NaN        NaN           NaN             NaN         NaN
#
#        provstate divert corp3_x approxdate                  attacktype_txt  \
# 64310    Central    NaN     NaN        NaN                   Armed Assault
# 64311  West Bank    NaN     NaN        NaN                   Armed Assault
# 64312   Oklahoma    NaN     NaN        NaN  Facility/Infrastructure Attack
# 64313   Oklahoma    NaN     NaN        NaN  Facility/Infrastructure Attack
# 64314   Oklahoma    NaN     NaN        NaN  Facility/Infrastructure Attack
#
#            ...                    natlty1_txt corp2 gsubname2_x  \
# 64310      ...                          Nepal   NaN         NaN
# 64311      ...       West Bank and Gaza Strip   NaN         NaN
# 64312      ...                  United States   NaN         NaN
# 64313      ...                  United States   NaN         NaN
# 64314      ...                  United States   NaN         NaN
#
#       alternative_txt corp3_y  \
# 64310             NaN     NaN
# 64311             NaN     NaN
# 64312             NaN     NaN
# 64313             NaN     NaN
# 64314             NaN     NaN
#
#                                       targsubtype1_txt weaptype1_txt  \
# 64310  Police Building (headquarters, station, school)      Firearms
# 64311                         Marketplace/Plaza/Square      Firearms
# 64312                                          Clinics    Incendiary
# 64313                                          Clinics    Incendiary
# 64314                                          Clinics    Incendiary
#
#       weaptype3_txt                  region_txt targtype2_txt
# 64310           NaN                  South Asia           NaN
# 64311           NaN  Middle East & North Africa           NaN
# 64312           NaN               North America           NaN
# 64313           NaN               North America           NaN
# 64314           NaN               North America           NaN
#
# [5 rows x 60 columns]

# %%
# Removes individual attacktype_txt columns
del data_for_analysis_new["attacktype1_txt"]
del data_for_analysis_new["attacktype2_txt"]
del data_for_analysis_new["attacktype3_txt"]

# %%
# Finds all possible categorical column pairs
cols = data_for_analysis_new.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('motive_y', 'gsubname_x'), ('motive_y', 'natlty3_txt_x'), ('motive_y', 'natlty2_txt'), ('motive_y', 'provstate'), ('motive_y', 'divert'), ('motive_y', 'corp3_x'), ('motive_y', 'approxdate'), ('motive_y', 'attacktype_txt'), ('motive_y', 'gname2_y'), ('motive_y', 'gname_y'), ('motive_y', 'gname2_x'), ('motive_y', 'target1'), ('motive_y', 'targtype3_txt_x'), ('motive_y', 'targtype1_txt'), ('motive_y', 'gsubname_y'), ('motive_y', 'natlty3_txt_y'), ('motive_y', 'motive_x'), ('motive_y', 'claimmode2_txt'), ('motive_y', 'target2'), ('motive_y', 'corp1'), ('motive_y', 'weapsubtype1_txt'), ('motive_y', 'claimmode3_txt'), ('motive_y', 'city'), ('motive_y', 'gsubname2_y'), ('motive_y', 'gname3_y'), ('motive_y', 'weaptype2_txt'), ('motive_y', 'targsubtype3_txt_y'), ('motive_y', 'gname_x'), ('motive_y', 'target3_x'), ('motive_y', 'hostkidoutcome_txt'), ('motive_y', 'gsubname3_x'), ('motive_y', 'weaptype4_txt'), ('motive_y', 'weapsubtype4_txt'), ('motive_y', 'propextent_txt'), ('motive_y', 'kidhijcountry'), ('motive_y', 'targsubtype2_txt'), ('motive_y', 'target3_y'), ('motive_y', 'targsubtype3_txt_x'), ('motive_y', 'weapsubtype2_txt'), ('motive_y', 'claimmode_txt'), ('motive_y', 'related'), ('motive_y', 'gname3_x'), ('motive_y', 'country_txt'), ('motive_y', 'weapsubtype3_txt'), ('motive_y', 'targtype3_txt_y'), ('motive_y', 'gsubname3_y'), ('motive_y', 'natlty1_txt'), ('motive_y', 'corp2'), ('motive_y', 'gsubname2_x'), ('motive_y', 'alternative_txt'), ('motive_y', 'corp3_y'), ('motive_y', 'targsubtype1_txt'), ('motive_y', 'weaptype1_txt'), ('motive_y', 'weaptype3_txt'), ('motive_y', 'region_txt'), ('motive_y', 'targtype2_txt'), ('gsubname_x', 'motive_y'), ('gsubname_x', 'natlty3_txt_x'), ('gsubname_x', 'natlty2_txt'), ('gsubname_x', 'provstate'), ('gsubname_x', 'divert'), ('gsubname_x', 'corp3_x'), ('gsubname_x', 'approxdate'), ('gsubname_x', 'attacktype_txt'), ('gsubname_x', 'gname2_y'), ('gsubname_x', 'gname_y'), ('gsubname_x', 'gname2_x'), ('gsubname_x', 'target1'), ('gsubname_x', 'targtype3_txt_x'), ('gsubname_x', 'targtype1_txt'), ('gsubname_x', 'gsubname_y'), ('gsubname_x', 'natlty3_txt_y'), ('gsubname_x', 'motive_x'), ('gsubname_x', 'claimmode2_txt'), ('gsubname_x', 'target2'), ('gsubname_x', 'corp1'), ('gsubname_x', 'weapsubtype1_txt'), ('gsubname_x', 'claimmode3_txt'), ('gsubname_x', 'city'), ('gsubname_x', 'gsubname2_y'), ('gsubname_x', 'gname3_y'), ('gsubname_x', 'weaptype2_txt'), ('gsubname_x', 'targsubtype3_txt_y'), ('gsubname_x', 'gname_x'), ('gsubname_x', 'target3_x'), ('gsubname_x', 'hostkidoutcome_txt'), ('gsubname_x', 'gsubname3_x'), ('gsubname_x', 'weaptype4_txt'), ('gsubname_x', 'weapsubtype4_txt'), ('gsubname_x', 'propextent_txt'), ('gsubname_x', 'kidhijcountry'), ('gsubname_x', 'targsubtype2_txt'), ('gsubname_x', 'target3_y'), ('gsubname_x', 'targsubtype3_txt_x'), ('gsubname_x', 'weapsubtype2_txt'), ('gsubname_x', 'claimmode_txt'), ('gsubname_x', 'related'), ('gsubname_x', 'gname3_x'), ('gsubname_x', 'country_txt'), ('gsubname_x', 'weapsubtype3_txt'), ('gsubname_x', 'targtype3_txt_y'), ('gsubname_x', 'gsubname3_y'), ('gsubname_x', 'natlty1_txt'), ('gsubname_x', 'corp2'), ('gsubname_x', 'gsubname2_x'), ('gsubname_x', 'alternative_txt'), ('gsubname_x', 'corp3_y'), ('gsubname_x', 'targsubtype1_txt'), ('gsubname_x', 'weaptype1_txt'), ('gsubname_x', 'weaptype3_txt'), ('gsubname_x', 'region_txt'), ('gsubname_x', 'targtype2_txt'), ('natlty3_txt_x', 'motive_y'), ('natlty3_txt_x', 'gsubname_x'), ('natlty3_txt_x', 'natlty2_txt'), ('natlty3_txt_x', 'provstate'), ('natlty3_txt_x', 'divert'), ('natlty3_txt_x', 'corp3_x'), ('natlty3_txt_x', 'approxdate'), ('natlty3_txt_x', 'attacktype_txt'), ('natlty3_txt_x', 'gname2_y'), ('natlty3_txt_x', 'gname_y'), ('natlty3_txt_x', 'gname2_x'), ('natlty3_txt_x', 'target1'), ('natlty3_txt_x', 'targtype3_txt_x'), ('natlty3_txt_x', 'targtype1_txt'), ('natlty3_txt_x', 'gsubname_y'), ('natlty3_txt_x', 'natlty3_txt_y'), ('natlty3_txt_x', 'motive_x'), ('natlty3_txt_x', 'claimmode2_txt'), ('natlty3_txt ...

# %%
calculate_chi_square_for_column(column_pairs, data_for_analysis_new, "attacktype_txt", 0.6)
# Out:
# Total pairs:  3192
# Current pair:  7 )  ('motive_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  63 )  ('gsubname_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  119 )  ('natlty3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  175 )  ('natlty2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  231 )  ('provstate', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  287 )  ('divert', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  343 )  ('corp3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  399 )  ('approxdate', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  448 )  ('attacktype_txt', 'motive_y')
# Insufficient data for analysis
# Current pair:  449 )  ('attacktype_txt', 'gsubname_x')
# Insufficient data for analysis
# Current pair:  450 )  ('attacktype_txt', 'natlty3_txt_x')
# Insufficient data for analysis
# Current pair:  451 )  ('attacktype_txt', 'natlty2_txt')
# Insufficient data for analysis
# Current pair:  452 )  ('attacktype_txt', 'provstate')
# Insufficient data for analysis
# Current pair:  453 )  ('attacktype_txt', 'divert')
# Insufficient data for analysis
# Current pair:  454 )  ('attacktype_txt', 'corp3_x')
# Insufficient data for analysis
# Current pair:  455 )  ('attacktype_txt', 'approxdate')
# Insufficient data for analysis
# Current pair:  456 )  ('attacktype_txt', 'gname2_y')
# Insufficient data for analysis
# Current pair:  457 )  ('attacktype_txt', 'gname_y')
# Insufficient data for analysis
# Current pair:  458 )  ('attacktype_txt', 'gname2_x')
# Insufficient data for analysis
# Current pair:  459 )  ('attacktype_txt', 'target1')
# Insufficient data for analysis
# Current pair:  460 )  ('attacktype_txt', 'targtype3_txt_x')
# Insufficient data for analysis
# Current pair:  461 )  ('attacktype_txt', 'targtype1_txt')
# Insufficient data for analysis
# Current pair:  462 )  ('attacktype_txt', 'gsubname_y')
# Insufficient data for analysis
# Current pair:  463 )  ('attacktype_txt', 'natlty3_txt_y')
# Insufficient data for analysis
# Current pair:  464 )  ('attacktype_txt', 'motive_x')
# Insufficient data for analysis
# Current pair:  465 )  ('attacktype_txt', 'claimmode2_txt')
# Insufficient data for analysis
# Current pair:  466 )  ('attacktype_txt', 'target2')
# Insufficient data for analysis
# Current pair:  467 )  ('attacktype_txt', 'corp1')
# Insufficient data for analysis
# Current pair:  468 )  ('attacktype_txt', 'weapsubtype1_txt')
# Insufficient data for analysis
# Current pair:  469 )  ('attacktype_txt', 'claimmode3_txt')
# Insufficient data for analysis
# Current pair:  470 )  ('attacktype_txt', 'city')
# Insufficient data for analysis
# Current pair:  471 )  ('attacktype_txt', 'gsubname2_y')
# Insufficient data for analysis
# Current pair:  472 )  ('attacktype_txt', 'gname3_y')
# Insufficient data for analysis
# Current pair:  473 )  ('attacktype_txt', 'weaptype2_txt')
# Insufficient data for analysis
# Current pair:  474 )  ('attacktype_txt', 'targsubtype3_txt_y')
# Insufficient data for analysis
# Current pair:  475 )  ('attacktype_txt', 'gname_x')
# Insufficient data for analysis
# Current pair:  476 )  ('attacktype_txt', 'target3_x')
# Insufficient data for analysis
# Current pair:  477 )  ('attacktype_txt', 'hostkidoutcome_txt')
# Insufficient data for analysis
# Current pair:  478 )  ('attacktype_txt', 'gsubname3_x')
# Insufficient data for analysis
# Current pair:  479 )  ('attacktype_txt', 'weaptype4_txt')
# Insufficient data for analysis
# Current pair:  480 )  ('attacktype_txt', 'weapsubtype4_txt')
# Insufficient data for analysis
# Current pair:  481 )  ('attacktype_txt', 'propextent_txt')
# Insufficient data for analysis
# Current pair:  482 )  ('attacktype_txt', 'kidhijcountry')
# Insufficient data for analysis
# Current pair:  483 )  ('attacktype_txt', 'targsubtype2_txt')
# Insufficient data for analysis
# Current pair:  484 )  ('attacktype_txt', 'target3_y')
# Insufficient data for analysis
# Current pair:  485 )  ('attacktype_txt', 'targsubtype3_txt_x')
# Insufficient data for analysis
# Current pair:  486 )  ('attacktype_txt', 'weapsubtype2_txt')
# Insufficient data for analysis
# Current pair:  487 )  ('attacktype_txt', 'claimmode_txt')
# Insufficient data for analysis
# Current pair:  488 )  ('attacktype_txt', 'related')
# Insufficient data for analysis
# Current pair:  489 )  ('attacktype_txt', 'gname3_x')
# Insufficient data for analysis
# Current pair:  490 )  ('attacktype_txt', 'country_txt')
# Insufficient data for analysis
# Current pair:  491 )  ('attacktype_txt', 'weapsubtype3_txt')
# Insufficient data for analysis
# Current pair:  492 )  ('attacktype_txt', 'targtype3_txt_y')
# Insufficient data for analysis
# Current pair:  493 )  ('attacktype_txt', 'gsubname3_y')
# Insufficient data for analysis
# Current pair:  494 )  ('attacktype_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  495 )  ('attacktype_txt', 'corp2')
# Insufficient data for analysis
# Current pair:  496 )  ('attacktype_txt', 'gsubname2_x')
# Insufficient data for analysis
# Current pair:  497 )  ('attacktype_txt', 'alternative_txt')
# Insufficient data for analysis
# Current pair:  498 )  ('attacktype_txt', 'corp3_y')
# Insufficient data for analysis
# Current pair:  499 )  ('attacktype_txt', 'targsubtype1_txt')
# Insufficient data for analysis
# Current pair:  500 )  ('attacktype_txt', 'weaptype1_txt')
# Insufficient data for analysis
# Current pair:  501 )  ('attacktype_txt', 'weaptype3_txt')
# Insufficient data for analysis
# Current pair:  502 )  ('attacktype_txt', 'region_txt')
# Insufficient data for analysis
# Current pair:  503 )  ('attacktype_txt', 'targtype2_txt')
# Insufficient data for analysis
# Current pair:  512 )  ('gname2_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  568 )  ('gname_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  624 )  ('gname2_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  680 )  ('target1', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  736 )  ('targtype3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  792 )  ('targtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  848 )  ('gsubname_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  904 )  ('natlty3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  960 )  ('motive_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1016 )  ('claimmode2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1072 )  ('target2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1128 )  ('corp1', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1184 )  ('weapsubtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1240 )  ('claimmode3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1296 )  ('city', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1352 )  ('gsubname2_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1408 )  ('gname3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1464 )  ('weaptype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1520 )  ('targsubtype3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1576 )  ('gname_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1632 )  ('target3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1688 )  ('hostkidoutcome_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1744 )  ('gsubname3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1800 )  ('weaptype4_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1856 )  ('weapsubtype4_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1912 )  ('propextent_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1968 )  ('kidhijcountry', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2024 )  ('targsubtype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2080 )  ('target3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2136 )  ('targsubtype3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2192 )  ('weapsubtype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2248 )  ('claimmode_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2304 )  ('related', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2360 )  ('gname3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2416 )  ('country_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2472 )  ('weapsubtype3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2528 )  ('targtype3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2584 )  ('gsubname3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2640 )  ('natlty1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2696 )  ('corp2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2752 )  ('gsubname2_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2808 )  ('alternative_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2864 )  ('corp3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2920 )  ('targsubtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2976 )  ('weaptype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3032 )  ('weaptype3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3088 )  ('region_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3144 )  ('targtype2_txt', 'attacktype_txt')
# Insufficient data for analysis

# %% [markdown]
# Found no correlation whith the treshold 60%.

# %%
calculate_chi_square_for_column(column_pairs, data_for_analysis_new, "attacktype_txt", 0.45)
# Out:
# Total pairs:  3192
# Current pair:  7 )  ('motive_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  63 )  ('gsubname_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  119 )  ('natlty3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  175 )  ('natlty2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  231 )  ('provstate', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  287 )  ('divert', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  343 )  ('corp3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  399 )  ('approxdate', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  448 )  ('attacktype_txt', 'motive_y')
# Insufficient data for analysis
# Current pair:  449 )  ('attacktype_txt', 'gsubname_x')
# Insufficient data for analysis
# Current pair:  450 )  ('attacktype_txt', 'natlty3_txt_x')
# Insufficient data for analysis
# Current pair:  451 )  ('attacktype_txt', 'natlty2_txt')
# Insufficient data for analysis
# Current pair:  452 )  ('attacktype_txt', 'provstate')
# Insufficient data for analysis
# Current pair:  453 )  ('attacktype_txt', 'divert')
# Insufficient data for analysis
# Current pair:  454 )  ('attacktype_txt', 'corp3_x')
# Insufficient data for analysis
# Current pair:  455 )  ('attacktype_txt', 'approxdate')
# Insufficient data for analysis
# Current pair:  456 )  ('attacktype_txt', 'gname2_y')
# Insufficient data for analysis
# Current pair:  457 )  ('attacktype_txt', 'gname_y')
# Insufficient data for analysis
# Current pair:  458 )  ('attacktype_txt', 'gname2_x')
# Insufficient data for analysis
# Current pair:  459 )  ('attacktype_txt', 'target1')
# Insufficient data for analysis
# Current pair:  460 )  ('attacktype_txt', 'targtype3_txt_x')
# Insufficient data for analysis
# Current pair:  461 )  ('attacktype_txt', 'targtype1_txt')
# Insufficient data for analysis
# Current pair:  462 )  ('attacktype_txt', 'gsubname_y')
# Insufficient data for analysis
# Current pair:  463 )  ('attacktype_txt', 'natlty3_txt_y')
# Insufficient data for analysis
# Current pair:  464 )  ('attacktype_txt', 'motive_x')
# Insufficient data for analysis
# Current pair:  465 )  ('attacktype_txt', 'claimmode2_txt')
# Insufficient data for analysis
# Current pair:  466 )  ('attacktype_txt', 'target2')
# Insufficient data for analysis
# Current pair:  467 )  ('attacktype_txt', 'corp1')
# Insufficient data for analysis
# Current pair:  468 )  ('attacktype_txt', 'weapsubtype1_txt')
# Insufficient data for analysis
# Current pair:  469 )  ('attacktype_txt', 'claimmode3_txt')
# Insufficient data for analysis
# Current pair:  470 )  ('attacktype_txt', 'city')
# Insufficient data for analysis
# Current pair:  471 )  ('attacktype_txt', 'gsubname2_y')
# Insufficient data for analysis
# Current pair:  472 )  ('attacktype_txt', 'gname3_y')
# Insufficient data for analysis
# Current pair:  473 )  ('attacktype_txt', 'weaptype2_txt')
# Insufficient data for analysis
# Current pair:  474 )  ('attacktype_txt', 'targsubtype3_txt_y')
# Insufficient data for analysis
# Current pair:  475 )  ('attacktype_txt', 'gname_x')
# Insufficient data for analysis
# Current pair:  476 )  ('attacktype_txt', 'target3_x')
# Insufficient data for analysis
# Current pair:  477 )  ('attacktype_txt', 'hostkidoutcome_txt')
# Insufficient data for analysis
# Current pair:  478 )  ('attacktype_txt', 'gsubname3_x')
# Insufficient data for analysis
# Current pair:  479 )  ('attacktype_txt', 'weaptype4_txt')
# Insufficient data for analysis
# Current pair:  480 )  ('attacktype_txt', 'weapsubtype4_txt')
# Insufficient data for analysis
# Current pair:  481 )  ('attacktype_txt', 'propextent_txt')
# Insufficient data for analysis
# Current pair:  482 )  ('attacktype_txt', 'kidhijcountry')
# Insufficient data for analysis
# Current pair:  483 )  ('attacktype_txt', 'targsubtype2_txt')
# Insufficient data for analysis
# Current pair:  484 )  ('attacktype_txt', 'target3_y')
# Insufficient data for analysis
# Current pair:  485 )  ('attacktype_txt', 'targsubtype3_txt_x')
# Insufficient data for analysis
# Current pair:  486 )  ('attacktype_txt', 'weapsubtype2_txt')
# Insufficient data for analysis
# Current pair:  487 )  ('attacktype_txt', 'claimmode_txt')
# Insufficient data for analysis
# Current pair:  488 )  ('attacktype_txt', 'related')
# Insufficient data for analysis
# Current pair:  489 )  ('attacktype_txt', 'gname3_x')
# Insufficient data for analysis
# Current pair:  490 )  ('attacktype_txt', 'country_txt')
# Insufficient data for analysis
# Current pair:  491 )  ('attacktype_txt', 'weapsubtype3_txt')
# Insufficient data for analysis
# Current pair:  492 )  ('attacktype_txt', 'targtype3_txt_y')
# Insufficient data for analysis
# Current pair:  493 )  ('attacktype_txt', 'gsubname3_y')
# Insufficient data for analysis
# Current pair:  494 )  ('attacktype_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  495 )  ('attacktype_txt', 'corp2')
# Insufficient data for analysis
# Current pair:  496 )  ('attacktype_txt', 'gsubname2_x')
# Insufficient data for analysis
# Current pair:  497 )  ('attacktype_txt', 'alternative_txt')
# Insufficient data for analysis
# Current pair:  498 )  ('attacktype_txt', 'corp3_y')
# Insufficient data for analysis
# Current pair:  499 )  ('attacktype_txt', 'targsubtype1_txt')
# Insufficient data for analysis
# Current pair:  500 )  ('attacktype_txt', 'weaptype1_txt')
# Insufficient data for analysis
# Current pair:  501 )  ('attacktype_txt', 'weaptype3_txt')
# Insufficient data for analysis
# Current pair:  502 )  ('attacktype_txt', 'region_txt')
# Insufficient data for analysis
# Current pair:  503 )  ('attacktype_txt', 'targtype2_txt')
# Insufficient data for analysis
# Current pair:  512 )  ('gname2_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  568 )  ('gname_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  624 )  ('gname2_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  680 )  ('target1', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  736 )  ('targtype3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  792 )  ('targtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  848 )  ('gsubname_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  904 )  ('natlty3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  960 )  ('motive_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1016 )  ('claimmode2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1072 )  ('target2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1128 )  ('corp1', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1184 )  ('weapsubtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1240 )  ('claimmode3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1296 )  ('city', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1352 )  ('gsubname2_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1408 )  ('gname3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1464 )  ('weaptype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1520 )  ('targsubtype3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1576 )  ('gname_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1632 )  ('target3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1688 )  ('hostkidoutcome_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1744 )  ('gsubname3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1800 )  ('weaptype4_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1856 )  ('weapsubtype4_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1912 )  ('propextent_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1968 )  ('kidhijcountry', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2024 )  ('targsubtype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2080 )  ('target3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2136 )  ('targsubtype3_txt_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2192 )  ('weapsubtype2_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2248 )  ('claimmode_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2304 )  ('related', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2360 )  ('gname3_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2416 )  ('country_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2472 )  ('weapsubtype3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2528 )  ('targtype3_txt_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2584 )  ('gsubname3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2640 )  ('natlty1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2696 )  ('corp2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2752 )  ('gsubname2_x', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2808 )  ('alternative_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2864 )  ('corp3_y', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2920 )  ('targsubtype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2976 )  ('weaptype1_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3032 )  ('weaptype3_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3088 )  ('region_txt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  3144 )  ('targtype2_txt', 'attacktype_txt')
# Insufficient data for analysis

# %% [markdown]
# Found no correlation with the treshold 45%. As a result, **there is no correlation between attacktype_txt and tcategorical columns**. Further analysis should be conducted to find correaltion between "attacktype_txt" and numerical columns. Such analysis requires ANOVA test.

# %% [markdown]
# ### ANOVA test

# %% [markdown]
# #### Before year 1997

# %%
# Lists all cnumerical columns
cols = data.columns
num_cols = data._get_numeric_data().columns
#num_cols.append("attacktype_txt")
print(type(num_cols))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_old = data_old[num_cols].copy(deep=True)
data_for_analysis_old = data_for_analysis_old.assign(attacktype_txt=data_old["attacktype_txt"].values)
del data_for_analysis_old["Unnamed: 0"]
del data_for_analysis_old["eventid"]
data_for_analysis_old.head()
# Out:
#    iyear  imonth  iday  extended   latitude   longitude  specificity  \
# 0   1970       7     2         0  18.456792  -69.951164          1.0
# 1   1970       0     0         0  19.371887  -99.086624          1.0
# 2   1970       1     0         0  15.478598  120.599741          4.0
# 3   1970       1     0         0  37.997490   23.762728          1.0
# 4   1970       1     0         0  33.580412  130.396361          1.0
#
#    vicinity  crit1  crit2               ...                nhostkidus  nhours  \
# 0       0.0      1      1               ...                       NaN     NaN
# 1       0.0      1      1               ...                       0.0     NaN
# 2       0.0      1      1               ...                       NaN     NaN
# 3       0.0      1      1               ...                       NaN     NaN
# 4       0.0      1      1               ...                       NaN     NaN
#
#    ndays  ransom  ransomamt  ransomamtus  ransompaid  ransompaidus  nreleased  \
# 0    NaN     0.0        NaN          NaN         NaN           NaN        NaN
# 1    NaN     1.0   800000.0          NaN         NaN           NaN        NaN
# 2    NaN     0.0        NaN          NaN         NaN           NaN        NaN
# 3    NaN     0.0        NaN          NaN         NaN           NaN        NaN
# 4    NaN     0.0        NaN          NaN         NaN           NaN        NaN
#
#                    attacktype_txt
# 0                   Assassination
# 1     Hostage Taking (Kidnapping)
# 2                   Assassination
# 3               Bombing/Explosion
# 4  Facility/Infrastructure Attack
#
# [5 rows x 45 columns]

# %%
# Finds all possible column pairs
cols = data_for_analysis_old.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('iyear', 'imonth'), ('iyear', 'iday'), ('iyear', 'extended'), ('iyear', 'latitude'), ('iyear', 'longitude'), ('iyear', 'specificity'), ('iyear', 'vicinity'), ('iyear', 'crit1'), ('iyear', 'crit2'), ('iyear', 'crit3'), ('iyear', 'doubtterr'), ('iyear', 'multiple'), ('iyear', 'success'), ('iyear', 'suicide'), ('iyear', 'guncertain1'), ('iyear', 'guncertain2'), ('iyear', 'guncertain3'), ('iyear', 'individual'), ('iyear', 'nperps'), ('iyear', 'nperpcap'), ('iyear', 'claimed'), ('iyear', 'claim2'), ('iyear', 'claim3'), ('iyear', 'compclaim'), ('iyear', 'nkill'), ('iyear', 'nkillus'), ('iyear', 'nkillter'), ('iyear', 'nwound'), ('iyear', 'nwoundus'), ('iyear', 'nwoundte'), ('iyear', 'property'), ('iyear', 'propvalue'), ('iyear', 'ishostkid'), ('iyear', 'nhostkid'), ('iyear', 'nhostkidus'), ('iyear', 'nhours'), ('iyear', 'ndays'), ('iyear', 'ransom'), ('iyear', 'ransomamt'), ('iyear', 'ransomamtus'), ('iyear', 'ransompaid'), ('iyear', 'ransompaidus'), ('iyear', 'nreleased'), ('iyear', 'attacktype_txt'), ('imonth', 'iyear'), ('imonth', 'iday'), ('imonth', 'extended'), ('imonth', 'latitude'), ('imonth', 'longitude'), ('imonth', 'specificity'), ('imonth', 'vicinity'), ('imonth', 'crit1'), ('imonth', 'crit2'), ('imonth', 'crit3'), ('imonth', 'doubtterr'), ('imonth', 'multiple'), ('imonth', 'success'), ('imonth', 'suicide'), ('imonth', 'guncertain1'), ('imonth', 'guncertain2'), ('imonth', 'guncertain3'), ('imonth', 'individual'), ('imonth', 'nperps'), ('imonth', 'nperpcap'), ('imonth', 'claimed'), ('imonth', 'claim2'), ('imonth', 'claim3'), ('imonth', 'compclaim'), ('imonth', 'nkill'), ('imonth', 'nkillus'), ('imonth', 'nkillter'), ('imonth', 'nwound'), ('imonth', 'nwoundus'), ('imonth', 'nwoundte'), ('imonth', 'property'), ('imonth', 'propvalue'), ('imonth', 'ishostkid'), ('imonth', 'nhostkid'), ('imonth', 'nhostkidus'), ('imonth', 'nhours'), ('imonth', 'ndays'), ('imonth', 'ransom'), ('imonth', 'ransomamt'), ('imonth', 'ransomamtus'), ('imonth', 'ransompaid'), ('imonth', 'ransompaidus'), ('imonth', 'nreleased'), ('imonth', 'attacktype_txt'), ('iday', 'iyear'), ('iday', 'imonth'), ('iday', 'extended'), ('iday', 'latitude'), ('iday', 'longitude'), ('iday', 'specificity'), ('iday', 'vicinity'), ('iday', 'crit1'), ('iday', 'crit2'), ('iday', 'crit3'), ('iday', 'doubtterr'), ('iday', 'multiple'), ('iday', 'success'), ('iday', 'suicide'), ('iday', 'guncertain1'), ('iday', 'guncertain2'), ('iday', 'guncertain3'), ('iday', 'individual'), ('iday', 'nperps'), ('iday', 'nperpcap'), ('iday', 'claimed'), ('iday', 'claim2'), ('iday', 'claim3'), ('iday', 'compclaim'), ('iday', 'nkill'), ('iday', 'nkillus'), ('iday', 'nkillter'), ('iday', 'nwound'), ('iday', 'nwoundus'), ('iday', 'nwoundte'), ('iday', 'property'), ('iday', 'propvalue'), ('iday', 'ishostkid'), ('iday', 'nhostkid'), ('iday', 'nhostkidus'), ('iday', 'nhours'), ('iday', 'ndays'), ('iday', 'ransom'), ('iday', 'ransomamt'), ('iday', 'ransomamtus'), ('iday', 'ransompaid'), ('iday', 'ransompaidus'), ('iday', 'nreleased'), ('iday', 'attacktype_txt'), ('extended', 'iyear'), ('extended', 'imonth'), ('extended', 'iday'), ('extended', 'latitude'), ('extended', 'longitude'), ('extended', 'specificity'), ('extended', 'vicinity'), ('extended', 'crit1'), ('extended', 'crit2'), ('extended', 'crit3'), ('extended', 'doubtterr'), ('extended', 'multiple'), ('extended', 'success'), ('extended', 'suicide'), ('extended', 'guncertain1'), ('extended', 'guncertain2'), ('extended', 'guncertain3'), ('extended', 'individual'), ('extended', 'nperps'), ('extended', 'nperpcap'), ('extended', 'claimed'), ('extended', 'claim2'), ('extended', 'claim3'), ('extended', 'compclaim'), ('extended', 'nkill'), ('extended', 'nkillus'), ('extended', 'nkillter'), ('extended', 'nwound'), ('extended', 'nwoundus'), ('extended', 'nwoundte'), ('extended', 'property'), ('extended', 'propvalue'), ('extended', 'ishostkid'), ('extended', 'nhostkid'), ('extended', 'nhostkidus'), ('extended', 'nhours'), ('extended', 'ndays'), ('extended', 'r ...

# %%
perform_anova_for_column(possible_pairs=column_pairs, data=data_for_analysis_old, column="attacktype_txt", treshold=0.6)
# Out:
# Total pairs:  1980
# Current pair:  43 )  ('iyear', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  87 )  ('imonth', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  131 )  ('iday', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  175 )  ('extended', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  219 )  ('latitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  263 )  ('longitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  307 )  ('specificity', 'attacktype_txt')
# /home/achaad/.local/lib/python3.6/site-packages/statsmodels/base/model.py:1100: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /home/achaad/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /home/achaad/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /home/achaad/.local/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            specificity   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     66.80
# Date:                Mon, 17 Dec 2018   Prob (F-statistic):          3.05e-294
# Time:                        02:25:37   Log-Likelihood:                -97093.
# No. Observations:               64310   AIC:                         1.942e+05
# Df Residuals:                   64287   BIC:                         1.944e+05
# Df Model:                          22
# Covariance Type:            nonrobust
# ============================================================================================================================================================================
#                                                                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                    1.6511      0.009    183.321      0.000       1.633       1.669
# attacktype_txt[T.Armed Assault, Armed Assault]                                                           -1.031e-15   1.01e-15     -1.025      0.305      -3e-15     9.4e-16
# attacktype_txt[T.Armed Assault, Assassination]                                                            1.213e-16   1.17e-15      0.104      0.917   -2.16e-15    2.41e-15
# attacktype_txt[T.Armed Assault, Bombing/Explosion]                                                          -0.3178      0.632     -0.503      0.615      -1.557       0.922
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Armed Assault]                                        -4.098e-16   8.89e-16     -0.461      0.645   -2.15e-15    1.33e-15
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Assassination]                                         9.178e-17   1.33e-16      0.691      0.490   -1.69e-16    3.52e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Bombing/Explosion]                                     4.329e-17   1.08e-16      0.400      0.689   -1.69e-16    2.55e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Facility/Infrastructure Attack]                       -7.179e-17    2.9e-16     -0.248      0.804    -6.4e-16    4.96e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Hostage Taking (Barricade Incident)]                   -8.64e-16   3.22e-16     -2.682      0.007    -1.5e-15   -2.33e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Hostage Taking (Kidnapping)]                          -3.139e-16   1.89e-16     -1.663      0.096   -6.84e-16    5.61e-17
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack]                                             -0.6511      0.548     -1.189      0.235      -1.725       0.422
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Armed Assault]                            3.684e-16   2.61e-16      1.414      0.157   -1.42e-16    8.79e-16
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Bombing/Explosion]                       -1.804e-16   1.84e-16     -0.979      0.328   -5.42e-16    1.81e-16
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Facility/Infrastructure Attack]           1.861e-16   3.43e-16      0.543      0.587   -4.86e-16    8.58e-16
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]              1.023e-16   1.71e-16      0.597      0.550   -2.33e-16    4.38e-16
# attacktype_txt[T.Armed Assault, Hijacking]                                                               -6.382e-17   1.56e-16     -0.408      0.683    -3.7e-16    2.42e-16
# attacktype_txt[T.Armed Assault, Hijacking, Hostage Taking (Kidnapping)]                                   1.004e-18   5.96e-18      0.169      0.866   -1.07e-17    1.27e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident)]                                      1.102e-18   6.01e-17      0.018      0.985   -1.17e-16    1.19e-16
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident), Assassination]                      -6.799e-18   1.01e-16     -0.067      0.947   -2.06e-16    1.92e-16
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)]         3.728e-18    5.7e-17      0.065      0.948   -1.08e-16    1.15e-16
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping)]                                              1.088e-18   4.07e-17      0.027      0.979   -7.87e-17    8.08e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Armed Assault]                               1.206e-19   6.04e-17      0.002      0.998   -1.18e-16    1.18e-16
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Bombing/Explosion]                          -5.361e-21   1.63e-18     -0.003      0.997    -3.2e-18    3.19e-18
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Facility/Infrastructure Attack]              2.687e-19   5.88e-17      0.005      0.996   -1.15e-16    1.16e-16
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Hijacking]                                  -2.299e-24   2.43e-16  -9.45e-09      1.000   -4.77e-16    4.77e-16
# attacktype_txt[T.Assassination]                                                                             -0.3482      0.014    -25.794      0.000      -0.375      -0.322
# attacktype_txt[T.Assassination, Armed Assault]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Armed Assault, Facility/Infrastructure Attack]                                    0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Bombing/Explosion]                                                                0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Facility/Infrastructure Attack]                                                   0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Barricade Incident)]                                              0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping)]                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping), Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping), Hijacking]                                     -0.6511      1.095     -0.594      0.552      -2.798       1.496
# attacktype_txt[T.Bombing/Explosion]                                                                         -0.3094      0.011    -27.620      0.000      -0.331      -0.287
# attacktype_txt[T.Bombing/Explosion, Armed Assault]                                                           0.1489      0.490      0.304      0.761      -0.811       1.109
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Armed Assault]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Assassination]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Bombing/Explosion]                                             0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Facility/Infrastructure Attack]                          -0.6511      1.095     -0.594      0.552      -2.798       1.496
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Hostage Taking (Barricade Incident)]                           0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Hostage Taking (Kidnapping)]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Assassination]                                                                0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Bombing/Explosion]                                                            0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Facility/Infrastructure Attack]                                         -0.6511      0.316     -2.059      0.040      -1.271      -0.031
# attacktype_txt[T.Bombing/Explosion, Facility/Infrastructure Attack, Armed Assault]                                0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hijacking]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hijacking, Hostage Taking (Kidnapping)]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Barricade Incident)]                                          0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping)]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Facility/Infrastructure Attack]                  0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Hijacking]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Unarmed Assault]                                                              0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Unknown]                                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack]                                                            -0.3891      0.019    -20.626      0.000      -0.426      -0.352
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault]                                             -0.6511      0.387     -1.681      0.093      -1.410       0.108
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Armed Assault]                                    0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Bombing/Explosion]                                0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Hostage Taking (Kidnapping)]                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Bombing/Explosion]                                               0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Bombing/Explosion, Hostage Taking (Kidnapping)]                  0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Barricade Incident)]                             0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]                                     0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping), Armed Assault]                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping), Bombing/Explosion]                  0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking]                                                                                 -0.2342      0.062     -3.779      0.000      -0.356      -0.113
# attacktype_txt[T.Hijacking, Armed Assault]                                                                  -0.6511      1.095     -0.594      0.552      -2.798       1.496
# attacktype_txt[T.Hijacking, Armed Assault, Hostage Taking (Kidnapping)]                                           0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Bombing/Explosion]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Facility/Infrastructure Attack]                                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]                          0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Barricade Incident)]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Barricade Incident), Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Kidnapping)]                                                          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident)]                                                       -0.3848      0.045     -8.517      0.000      -0.473      -0.296
# attacktype_txt[T.Hostage Taking (Barricade Incident), Armed Assault]                                        -0.6511      0.775     -0.841      0.401      -2.169       0.867
# attacktype_txt[T.Hostage Taking (Barricade Incident), Armed Assault, Facility/Infrastructure Attack]              0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion]                                    -0.6511      0.548     -1.189      0.235      -1.725       0.422
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Armed Assault]                           0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Facility/Infrastructure Attack]          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Unarmed Assault]                         0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Facility/Infrastructure Attack]                       -0.6511      1.095     -0.594      0.552      -2.798       1.496
# attacktype_txt[T.Hostage Taking (Barricade Incident), Facility/Infrastructure Attack, Armed Assault]        -0.6511      1.095     -0.594      0.552      -2.798       1.496
# attacktype_txt[T.Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)]                                0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Unarmed Assault]                                            0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping)]                                                                0.0255      0.023      1.108      0.268      -0.020       0.071
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault]                                                -0.6511      0.490     -1.329      0.184      -1.611       0.309
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Assassination]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Bombing/Explosion]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Facility/Infrastructure Attack]                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Hostage Taking (Kidnapping)]                         0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Assassination]                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Assassination, Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Facility/Infrastructure Attack]                  0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Hostage Taking (Kidnapping)]                     0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Facility/Infrastructure Attack]                               -0.6511      0.775     -0.841      0.401      -2.169       0.867
# attacktype_txt[T.Hostage Taking (Kidnapping), Facility/Infrastructure Attack, Armed Assault]                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hijacking]                                                          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Barricade Incident)]                                0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Barricade Incident), Armed Assault]                 0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Kidnapping)]                                        0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unarmed Assault]                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unarmed Assault, Facility/Infrastructure Attack]                    0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unknown]                                                            0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault]                                                                           -0.3966      0.061     -6.506      0.000      -0.516      -0.277
# attacktype_txt[T.Unarmed Assault, Bombing/Explosion, Facility/Infrastructure Attack]                              0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault, Facility/Infrastructure Attack]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault, Hijacking, Facility/Infrastructure Attack]                                      0          0        nan        nan           0           0
# attacktype_txt[T.Unknown]                                                                                    0.1534      0.025      6.201      0.000       0.105       0.202
# ==============================================================================
# Omnibus:                    28605.466   Durbin-Watson:                   1.504
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           104739.426
# Skew:                           2.343   Prob(JB):                         0.00
# Kurtosis:                       7.139   Cond. No.                     6.61e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.84e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Current pair:  351 )  ('vicinity', 'attacktype_txt')
# The F-statistic and p-value are too low
#
# Current pair:  395 )  ('crit1', 'attacktype_txt')
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  crit1   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     57.41
# Date:                Mon, 17 Dec 2018   Prob (F-statistic):          5.57e-251
# Time:                        02:25:40   Log-Likelihood:                 51356.
# No. Observations:               64310   AIC:                        -1.027e+05
# Df Residuals:                   64287   BIC:                        -1.025e+05
# Df Model:                          22
# Covariance Type:            nonrobust
# ============================================================================================================================================================================
#                                                                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                    0.9863      0.001   1101.349      0.000       0.985       0.988
# attacktype_txt[T.Armed Assault, Armed Assault]                                                           -1.029e-16      1e-16     -1.030      0.303   -2.99e-16     9.3e-17
# attacktype_txt[T.Armed Assault, Assassination]                                                            1.091e-16   1.16e-16      0.941      0.346   -1.18e-16    3.36e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion]                                                           0.0137      0.063      0.218      0.827      -0.110       0.137
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Armed Assault]                                        -3.101e-17   8.84e-17     -0.351      0.726   -2.04e-16    1.42e-16
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Assassination]                                          2.65e-17   1.32e-17      2.005      0.045    5.95e-19    5.24e-17
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Bombing/Explosion]                                    -5.971e-19   1.08e-17     -0.056      0.956   -2.17e-17    2.05e-17
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Facility/Infrastructure Attack]                       -1.539e-18   2.88e-17     -0.053      0.957    -5.8e-17    5.49e-17
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Hostage Taking (Barricade Incident)]                  -1.127e-17    3.2e-17     -0.352      0.725    -7.4e-17    5.15e-17
# attacktype_txt[T.Armed Assault, Bombing/Explosion, Hostage Taking (Kidnapping)]                           1.093e-17   1.88e-17      0.582      0.560   -2.59e-17    4.77e-17
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack]                                              0.0137      0.054      0.252      0.801      -0.093       0.120
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Armed Assault]                           -1.044e-17   2.59e-17     -0.403      0.687   -6.12e-17    4.03e-17
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Bombing/Explosion]                       -1.712e-17   1.83e-17     -0.934      0.350    -5.3e-17    1.88e-17
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Facility/Infrastructure Attack]          -1.209e-17   3.41e-17     -0.355      0.723   -7.89e-17    5.47e-17
# attacktype_txt[T.Armed Assault, Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]              6.576e-18    1.7e-17      0.386      0.699   -2.68e-17    3.99e-17
# attacktype_txt[T.Armed Assault, Hijacking]                                                               -7.141e-19   1.55e-17     -0.046      0.963   -3.12e-17    2.97e-17
# attacktype_txt[T.Armed Assault, Hijacking, Hostage Taking (Kidnapping)]                                   2.527e-19   5.93e-19      0.427      0.670   -9.09e-19    1.41e-18
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident)]                                      3.678e-20   5.97e-18      0.006      0.995   -1.17e-17    1.17e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident), Assassination]                      -2.269e-19   1.01e-17     -0.022      0.982      -2e-17    1.95e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)]         1.244e-19   5.67e-18      0.022      0.982    -1.1e-17    1.12e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping)]                                              3.631e-20   4.05e-18      0.009      0.993   -7.89e-18    7.97e-18
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Armed Assault]                               4.022e-21      6e-18      0.001      0.999   -1.18e-17    1.18e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Bombing/Explosion]                          -1.788e-22   1.62e-19     -0.001      0.999   -3.18e-19    3.18e-19
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Facility/Infrastructure Attack]              8.966e-21   5.85e-18      0.002      0.999   -1.15e-17    1.15e-17
# attacktype_txt[T.Armed Assault, Hostage Taking (Kidnapping), Hijacking]                                  -7.669e-26   2.42e-17  -3.17e-09      1.000   -4.74e-17    4.74e-17
# attacktype_txt[T.Assassination]                                                                             -0.0245      0.001    -18.230      0.000      -0.027      -0.022
# attacktype_txt[T.Assassination, Armed Assault]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Armed Assault, Facility/Infrastructure Attack]                                    0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Bombing/Explosion]                                                                0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Facility/Infrastructure Attack]                                                   0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Barricade Incident)]                                              0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping)]                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping), Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Assassination, Hostage Taking (Kidnapping), Hijacking]                                      0.0137      0.109      0.126      0.900      -0.200       0.227
# attacktype_txt[T.Bombing/Explosion]                                                                          0.0135      0.001     12.094      0.000       0.011       0.016
# attacktype_txt[T.Bombing/Explosion, Armed Assault]                                                           0.0137      0.049      0.282      0.778      -0.082       0.109
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Armed Assault]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Assassination]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Bombing/Explosion]                                             0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Facility/Infrastructure Attack]                           0.0137      0.109      0.126      0.900      -0.200       0.227
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Hostage Taking (Barricade Incident)]                           0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Armed Assault, Hostage Taking (Kidnapping)]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Assassination]                                                                0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Bombing/Explosion]                                                            0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Facility/Infrastructure Attack]                                          0.0137      0.031      0.436      0.662      -0.048       0.075
# attacktype_txt[T.Bombing/Explosion, Facility/Infrastructure Attack, Armed Assault]                                0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hijacking]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hijacking, Hostage Taking (Kidnapping)]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Barricade Incident)]                                          0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping)]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Facility/Infrastructure Attack]                  0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Hostage Taking (Kidnapping), Hijacking]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Unarmed Assault]                                                              0          0        nan        nan           0           0
# attacktype_txt[T.Bombing/Explosion, Unknown]                                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack]                                                             0.0130      0.002      6.952      0.000       0.009       0.017
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault]                                              0.0137      0.039      0.356      0.722      -0.062       0.089
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Armed Assault]                                    0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Bombing/Explosion]                                0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Armed Assault, Hostage Taking (Kidnapping)]                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Bombing/Explosion]                                               0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Bombing/Explosion, Hostage Taking (Kidnapping)]                  0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Barricade Incident)]                             0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]                                     0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping), Armed Assault]                      0          0        nan        nan           0           0
# attacktype_txt[T.Facility/Infrastructure Attack, Hostage Taking (Kidnapping), Bombing/Explosion]                  0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking]                                                                                  0.0106      0.006      1.719      0.086      -0.001       0.023
# attacktype_txt[T.Hijacking, Armed Assault]                                                                   0.0137      0.109      0.126      0.900      -0.200       0.227
# attacktype_txt[T.Hijacking, Armed Assault, Hostage Taking (Kidnapping)]                                           0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Bombing/Explosion]                                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Facility/Infrastructure Attack]                                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Facility/Infrastructure Attack, Hostage Taking (Kidnapping)]                          0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Barricade Incident)]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Barricade Incident), Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hijacking, Hostage Taking (Kidnapping)]                                                          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident)]                                                       -0.0026      0.004     -0.582      0.561      -0.011       0.006
# attacktype_txt[T.Hostage Taking (Barricade Incident), Armed Assault]                                         0.0137      0.077      0.178      0.859      -0.137       0.165
# attacktype_txt[T.Hostage Taking (Barricade Incident), Armed Assault, Facility/Infrastructure Attack]              0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion]                                     0.0137      0.054      0.252      0.801      -0.093       0.120
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Armed Assault]                           0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Facility/Infrastructure Attack]          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Bombing/Explosion, Unarmed Assault]                         0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Facility/Infrastructure Attack]                        0.0137      0.109      0.126      0.900      -0.200       0.227
# attacktype_txt[T.Hostage Taking (Barricade Incident), Facility/Infrastructure Attack, Armed Assault]         0.0137      0.109      0.126      0.900      -0.200       0.227
# attacktype_txt[T.Hostage Taking (Barricade Incident), Hostage Taking (Kidnapping)]                                0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Barricade Incident), Unarmed Assault]                                            0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping)]                                                               -0.0257      0.002    -11.198      0.000      -0.030      -0.021
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault]                                                -0.1863      0.049     -3.824      0.000      -0.282      -0.091
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Assassination]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Bombing/Explosion]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Facility/Infrastructure Attack]                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Armed Assault, Hostage Taking (Kidnapping)]                         0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Assassination]                                                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Assassination, Armed Assault]                                       0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion]                                                  0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Armed Assault]                                   0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Facility/Infrastructure Attack]                  0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Bombing/Explosion, Hostage Taking (Kidnapping)]                     0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Facility/Infrastructure Attack]                                0.0137      0.077      0.178      0.859      -0.137       0.165
# attacktype_txt[T.Hostage Taking (Kidnapping), Facility/Infrastructure Attack, Armed Assault]                      0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hijacking]                                                          0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Barricade Incident)]                                0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Barricade Incident), Armed Assault]                 0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Hostage Taking (Kidnapping)]                                        0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unarmed Assault]                                                    0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unarmed Assault, Facility/Infrastructure Attack]                    0          0        nan        nan           0           0
# attacktype_txt[T.Hostage Taking (Kidnapping), Unknown]                                                            0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault]                                                                            0.0077      0.006      1.265      0.206      -0.004       0.020
# attacktype_txt[T.Unarmed Assault, Bombing/Explosion, Facility/Infrastructure Attack]                              0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault, Facility/Infrastructure Attack]                                                 0          0        nan        nan           0           0
# attacktype_txt[T.Unarmed Assault, Hijacking, Facility/Infrastructure Attack]                                      0          0        nan        nan           0           0
# attacktype_txt[T.Unknown]                                                                                    0.0128      0.002      5.223      0.000       0.008       0.018
# ==============================================================================
# Omnibus:                    90015.121   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15378142.696
# Skew:                          -8.613   Prob(JB):                         0.00
# Kurtosis:                      76.772   Cond. No.                     6.61e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.84e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Current pair:  439 )  ('crit2', 'attacktype_txt')
# The F-statistic and p-value are too low
#
# Current pair:  483 )  ('crit3', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  527 )  ('doubtterr', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  571 )  ('multiple', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  615 )  ('success', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  659 )  ('suicide', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  703 )  ('guncertain1', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  747 )  ('guncertain2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  791 )  ('guncertain3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  835 )  ('individual', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  879 )  ('nperps', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  923 )  ('nperpcap', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  967 )  ('claimed', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1011 )  ('claim2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1055 )  ('claim3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1099 )  ('compclaim', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1143 )  ('nkill', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1187 )  ('nkillus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1231 )  ('nkillter', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1275 )  ('nwound', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1319 )  ('nwoundus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1363 )  ('nwoundte', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1407 )  ('property', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1451 )  ('propvalue', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1495 )  ('ishostkid', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1539 )  ('nhostkid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1583 )  ('nhostkidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1627 )  ('nhours', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1671 )  ('ndays', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1715 )  ('ransom', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1759 )  ('ransomamt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1803 )  ('ransomamtus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1847 )  ('ransompaid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1891 )  ('ransompaidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1935 )  ('nreleased', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1936 )  ('attacktype_txt', 'iyear')
#
# Could not calculate ANOVA results
#
# Current pair:  1937 )  ('attacktype_txt', 'imonth')
#
# Could not calculate ANOVA results
#
# Current pair:  1938 )  ('attacktype_txt', 'iday')
#
# Could not calculate ANOVA results
#
# Current pair:  1939 )  ('attacktype_txt', 'extended')
#
# Could not calculate ANOVA results
#
# Current pair:  1940 )  ('attacktype_txt', 'latitude')
#
# Could not calculate ANOVA results
#
# Current pair:  1941 )  ('attacktype_txt', 'longitude')
#
# Could not calculate ANOVA results
#
# Current pair:  1942 )  ('attacktype_txt', 'specificity')
#
# Could not calculate ANOVA results
#
# Current pair:  1943 )  ('attacktype_txt', 'vicinity')
#
# Could not calculate ANOVA results
#
# Current pair:  1944 )  ('attacktype_txt', 'crit1')
#
# Could not calculate ANOVA results
#
# Current pair:  1945 )  ('attacktype_txt', 'crit2')
#
# Could not calculate ANOVA results
#
# Current pair:  1946 )  ('attacktype_txt', 'crit3')
#
# Could not calculate ANOVA results
#
# Current pair:  1947 )  ('attacktype_txt', 'doubtterr')
#
# Could not calculate ANOVA results
#
# Current pair:  1948 )  ('attacktype_txt', 'multiple')
#
# Could not calculate ANOVA results
#
# Current pair:  1949 )  ('attacktype_txt', 'success')
#
# Could not calculate ANOVA results
#
# Current pair:  1950 )  ('attacktype_txt', 'suicide')
#
# Could not calculate ANOVA results
#
# Current pair:  1951 )  ('attacktype_txt', 'guncertain1')
#
# Could not calculate ANOVA results
#
# Current pair:  1952 )  ('attacktype_txt', 'guncertain2')
# Insufficient data for analysis
# Current pair:  1953 )  ('attacktype_txt', 'guncertain3')
# Insufficient data for analysis
# Current pair:  1954 )  ('attacktype_txt', 'individual')
# Insufficient data for analysis
# Current pair:  1955 )  ('attacktype_txt', 'nperps')
# Insufficient data for analysis
# Current pair:  1956 )  ('attacktype_txt', 'nperpcap')
# Insufficient data for analysis
# Current pair:  1957 )  ('attacktype_txt', 'claimed')
# Insufficient data for analysis
# Current pair:  1958 )  ('attacktype_txt', 'claim2')
# Insufficient data for analysis
# Current pair:  1959 )  ('attacktype_txt', 'claim3')
# Insufficient data for analysis
# Current pair:  1960 )  ('attacktype_txt', 'compclaim')
# Insufficient data for analysis
# Current pair:  1961 )  ('attacktype_txt', 'nkill')
#
# Could not calculate ANOVA results
#
# Current pair:  1962 )  ('attacktype_txt', 'nkillus')
# Insufficient data for analysis
# Current pair:  1963 )  ('attacktype_txt', 'nkillter')
# Insufficient data for analysis
# Current pair:  1964 )  ('attacktype_txt', 'nwound')
#
# Could not calculate ANOVA results
#
# Current pair:  1965 )  ('attacktype_txt', 'nwoundus')
# Insufficient data for analysis
# Current pair:  1966 )  ('attacktype_txt', 'nwoundte')
# Insufficient data for analysis
# Current pair:  1967 )  ('attacktype_txt', 'property')
#
# Could not calculate ANOVA results
#
# Current pair:  1968 )  ('attacktype_txt', 'propvalue')
# Insufficient data for analysis
# Current pair:  1969 )  ('attacktype_txt', 'ishostkid')
#
# Could not calculate ANOVA results
#
# Current pair:  1970 )  ('attacktype_txt', 'nhostkid')
# Insufficient data for analysis
# Current pair:  1971 )  ('attacktype_txt', 'nhostkidus')
# Insufficient data for analysis
# Current pair:  1972 )  ('attacktype_txt', 'nhours')
# Insufficient data for analysis
# Current pair:  1973 )  ('attacktype_txt', 'ndays')
# Insufficient data for analysis
# Current pair:  1974 )  ('attacktype_txt', 'ransom')
#
# Could not calculate ANOVA results
#
# Current pair:  1975 )  ('attacktype_txt', 'ransomamt')
# Insufficient data for analysis
# Current pair:  1976 )  ('attacktype_txt', 'ransomamtus')
# Insufficient data for analysis
# Current pair:  1977 )  ('attacktype_txt', 'ransompaid')
# Insufficient data for analysis
# Current pair:  1978 )  ('attacktype_txt', 'ransompaidus')
# Insufficient data for analysis
# Current pair:  1979 )  ('attacktype_txt', 'nreleased')
# Insufficient data for analysis

# %% [markdown]
# The ANOVA test shows that there is some correlation between specificity and attacktype. Further inspection shows that specificity is a categorical value and should have been converted to that. ANOVA test results are invalid for this column.

# %% [markdown]
# The ANOVA test showed strong correlation between crit1 and attacktype_txt. The reason for that could lie in fact that the most popular attacktype is explosion which constitutes to more than half of the incidents. And most incidents fulfill crit1 so this test result is not invalid per se but does not show much.

# %% [markdown]
# #### After 1997

# %%
# Lists all cnumerical columns
cols = data.columns
num_cols = data._get_numeric_data().columns
#num_cols.append("attacktype_txt")
print(type(num_cols))

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_new = data_new[num_cols].copy(deep=True)
data_for_analysis_new = data_for_analysis_new.assign(attacktype_txt=data_new["attacktype_txt"].values)
del data_for_analysis_new["Unnamed: 0"]
#del data_for_analysis_new["eventid"]
data_for_analysis_new.head()
# Out:
#             eventid  iyear  imonth  iday  extended   latitude  longitude  \
# 64310  199701010001   1997       1     1         0  27.493003  85.824033
# 64311  199701010002   1997       1     1         0  31.530243  35.094162
# 64312  199701010003   1997       1     1         0  36.149745 -95.993334
# 64313  199701010004   1997       1     1         0  36.149745 -95.993334
# 64314  199701010005   1997       1     1         0  36.149745 -95.993334
#
#        specificity  vicinity  crit1               ...                \
# 64310          1.0       1.0      1               ...
# 64311          1.0       0.0      1               ...
# 64312          1.0       0.0      1               ...
# 64313          1.0       0.0      1               ...
# 64314          1.0       0.0      1               ...
#
#        nhostkidus  nhours  ndays  ransom  ransomamt  ransomamtus  ransompaid  \
# 64310         NaN     NaN    NaN     0.0        NaN          NaN         NaN
# 64311         NaN     NaN    NaN     0.0        NaN          NaN         NaN
# 64312         NaN     NaN    NaN     0.0        NaN          NaN         NaN
# 64313         NaN     NaN    NaN     0.0        NaN          NaN         NaN
# 64314         NaN     NaN    NaN     0.0        NaN          NaN         NaN
#
#        ransompaidus  nreleased                  attacktype_txt
# 64310           NaN        NaN                   Armed Assault
# 64311           NaN        NaN                   Armed Assault
# 64312           NaN        NaN  Facility/Infrastructure Attack
# 64313           NaN        NaN  Facility/Infrastructure Attack
# 64314           NaN        NaN  Facility/Infrastructure Attack
#
# [5 rows x 46 columns]

# %%
# Finds all possible column pairs
cols = data_for_analysis_new.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('eventid', 'iyear'), ('eventid', 'imonth'), ('eventid', 'iday'), ('eventid', 'extended'), ('eventid', 'latitude'), ('eventid', 'longitude'), ('eventid', 'specificity'), ('eventid', 'vicinity'), ('eventid', 'crit1'), ('eventid', 'crit2'), ('eventid', 'crit3'), ('eventid', 'doubtterr'), ('eventid', 'multiple'), ('eventid', 'success'), ('eventid', 'suicide'), ('eventid', 'guncertain1'), ('eventid', 'guncertain2'), ('eventid', 'guncertain3'), ('eventid', 'individual'), ('eventid', 'nperps'), ('eventid', 'nperpcap'), ('eventid', 'claimed'), ('eventid', 'claim2'), ('eventid', 'claim3'), ('eventid', 'compclaim'), ('eventid', 'nkill'), ('eventid', 'nkillus'), ('eventid', 'nkillter'), ('eventid', 'nwound'), ('eventid', 'nwoundus'), ('eventid', 'nwoundte'), ('eventid', 'property'), ('eventid', 'propvalue'), ('eventid', 'ishostkid'), ('eventid', 'nhostkid'), ('eventid', 'nhostkidus'), ('eventid', 'nhours'), ('eventid', 'ndays'), ('eventid', 'ransom'), ('eventid', 'ransomamt'), ('eventid', 'ransomamtus'), ('eventid', 'ransompaid'), ('eventid', 'ransompaidus'), ('eventid', 'nreleased'), ('eventid', 'attacktype_txt'), ('iyear', 'eventid'), ('iyear', 'imonth'), ('iyear', 'iday'), ('iyear', 'extended'), ('iyear', 'latitude'), ('iyear', 'longitude'), ('iyear', 'specificity'), ('iyear', 'vicinity'), ('iyear', 'crit1'), ('iyear', 'crit2'), ('iyear', 'crit3'), ('iyear', 'doubtterr'), ('iyear', 'multiple'), ('iyear', 'success'), ('iyear', 'suicide'), ('iyear', 'guncertain1'), ('iyear', 'guncertain2'), ('iyear', 'guncertain3'), ('iyear', 'individual'), ('iyear', 'nperps'), ('iyear', 'nperpcap'), ('iyear', 'claimed'), ('iyear', 'claim2'), ('iyear', 'claim3'), ('iyear', 'compclaim'), ('iyear', 'nkill'), ('iyear', 'nkillus'), ('iyear', 'nkillter'), ('iyear', 'nwound'), ('iyear', 'nwoundus'), ('iyear', 'nwoundte'), ('iyear', 'property'), ('iyear', 'propvalue'), ('iyear', 'ishostkid'), ('iyear', 'nhostkid'), ('iyear', 'nhostkidus'), ('iyear', 'nhours'), ('iyear', 'ndays'), ('iyear', 'ransom'), ('iyear', 'ransomamt'), ('iyear', 'ransomamtus'), ('iyear', 'ransompaid'), ('iyear', 'ransompaidus'), ('iyear', 'nreleased'), ('iyear', 'attacktype_txt'), ('imonth', 'eventid'), ('imonth', 'iyear'), ('imonth', 'iday'), ('imonth', 'extended'), ('imonth', 'latitude'), ('imonth', 'longitude'), ('imonth', 'specificity'), ('imonth', 'vicinity'), ('imonth', 'crit1'), ('imonth', 'crit2'), ('imonth', 'crit3'), ('imonth', 'doubtterr'), ('imonth', 'multiple'), ('imonth', 'success'), ('imonth', 'suicide'), ('imonth', 'guncertain1'), ('imonth', 'guncertain2'), ('imonth', 'guncertain3'), ('imonth', 'individual'), ('imonth', 'nperps'), ('imonth', 'nperpcap'), ('imonth', 'claimed'), ('imonth', 'claim2'), ('imonth', 'claim3'), ('imonth', 'compclaim'), ('imonth', 'nkill'), ('imonth', 'nkillus'), ('imonth', 'nkillter'), ('imonth', 'nwound'), ('imonth', 'nwoundus'), ('imonth', 'nwoundte'), ('imonth', 'property'), ('imonth', 'propvalue'), ('imonth', 'ishostkid'), ('imonth', 'nhostkid'), ('imonth', 'nhostkidus'), ('imonth', 'nhours'), ('imonth', 'ndays'), ('imonth', 'ransom'), ('imonth', 'ransomamt'), ('imonth', 'ransomamtus'), ('imonth', 'ransompaid'), ('imonth', 'ransompaidus'), ('imonth', 'nreleased'), ('imonth', 'attacktype_txt'), ('iday', 'eventid'), ('iday', 'iyear'), ('iday', 'imonth'), ('iday', 'extended'), ('iday', 'latitude'), ('iday', 'longitude'), ('iday', 'specificity'), ('iday', 'vicinity'), ('iday', 'crit1'), ('iday', 'crit2'), ('iday', 'crit3'), ('iday', 'doubtterr'), ('iday', 'multiple'), ('iday', 'success'), ('iday', 'suicide'), ('iday', 'guncertain1'), ('iday', 'guncertain2'), ('iday', 'guncertain3'), ('iday', 'individual'), ('iday', 'nperps'), ('iday', 'nperpcap'), ('iday', 'claimed'), ('iday', 'claim2'), ('iday', 'claim3'), ('iday', 'compclaim'), ('iday', 'nkill'), ('iday', 'nkillus'), ('iday', 'nkillter'), ('iday', 'nwound'), ('iday', 'nwoundus'), ('iday', 'nwoundte'), ('iday', 'property'), ('iday', 'propvalue'), ('iday', 'ishostkid'), ('iday', 'nhostkid'), ('i ...

# %%
perform_anova_for_column(possible_pairs=column_pairs, data=data_for_analysis_new, column="attacktype_txt", treshold=0.6)
# Out:
# Total pairs:  2070
# Current pair:  44 )  ('eventid', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  89 )  ('iyear', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  134 )  ('imonth', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  179 )  ('iday', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  224 )  ('extended', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  269 )  ('latitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  314 )  ('longitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  359 )  ('specificity', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  404 )  ('vicinity', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  449 )  ('crit1', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  494 )  ('crit2', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  539 )  ('crit3', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  584 )  ('doubtterr', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  629 )  ('multiple', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  674 )  ('success', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  719 )  ('suicide', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  764 )  ('guncertain1', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  809 )  ('guncertain2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  854 )  ('guncertain3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  899 )  ('individual', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  944 )  ('nperps', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  989 )  ('nperpcap', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1034 )  ('claimed', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1079 )  ('claim2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1124 )  ('claim3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1169 )  ('compclaim', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1214 )  ('nkill', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1259 )  ('nkillus', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1304 )  ('nkillter', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1349 )  ('nwound', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1394 )  ('nwoundus', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1439 )  ('nwoundte', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1484 )  ('property', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1529 )  ('propvalue', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1574 )  ('ishostkid', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1619 )  ('nhostkid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1664 )  ('nhostkidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1709 )  ('nhours', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1754 )  ('ndays', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1799 )  ('ransom', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1844 )  ('ransomamt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1889 )  ('ransomamtus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1934 )  ('ransompaid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1979 )  ('ransompaidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2024 )  ('nreleased', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2025 )  ('attacktype_txt', 'eventid')
#
# Could not calculate ANOVA results
#
# Current pair:  2026 )  ('attacktype_txt', 'iyear')
#
# Could not calculate ANOVA results
#
# Current pair:  2027 )  ('attacktype_txt', 'imonth')
#
# Could not calculate ANOVA results
#
# Current pair:  2028 )  ('attacktype_txt', 'iday')
#
# Could not calculate ANOVA results
#
# Current pair:  2029 )  ('attacktype_txt', 'extended')
#
# Could not calculate ANOVA results
#
# Current pair:  2030 )  ('attacktype_txt', 'latitude')
#
# Could not calculate ANOVA results
#
# Current pair:  2031 )  ('attacktype_txt', 'longitude')
#
# Could not calculate ANOVA results
#
# Current pair:  2032 )  ('attacktype_txt', 'specificity')
#
# Could not calculate ANOVA results
#
# Current pair:  2033 )  ('attacktype_txt', 'vicinity')
#
# Could not calculate ANOVA results
#
# Current pair:  2034 )  ('attacktype_txt', 'crit1')
#
# Could not calculate ANOVA results
#
# Current pair:  2035 )  ('attacktype_txt', 'crit2')
#
# Could not calculate ANOVA results
#
# Current pair:  2036 )  ('attacktype_txt', 'crit3')
#
# Could not calculate ANOVA results
#
# Current pair:  2037 )  ('attacktype_txt', 'doubtterr')
#
# Could not calculate ANOVA results
#
# Current pair:  2038 )  ('attacktype_txt', 'multiple')
#
# Could not calculate ANOVA results
#
# Current pair:  2039 )  ('attacktype_txt', 'success')
#
# Could not calculate ANOVA results
#
# Current pair:  2040 )  ('attacktype_txt', 'suicide')
#
# Could not calculate ANOVA results
#
# Current pair:  2041 )  ('attacktype_txt', 'guncertain1')
#
# Could not calculate ANOVA results
#
# Current pair:  2042 )  ('attacktype_txt', 'guncertain2')
# Insufficient data for analysis
# Current pair:  2043 )  ('attacktype_txt', 'guncertain3')
# Insufficient data for analysis
# Current pair:  2044 )  ('attacktype_txt', 'individual')
#
# Could not calculate ANOVA results
#
# Current pair:  2045 )  ('attacktype_txt', 'nperps')
# Insufficient data for analysis
# Current pair:  2046 )  ('attacktype_txt', 'nperpcap')
#
# Could not calculate ANOVA results
#
# Current pair:  2047 )  ('attacktype_txt', 'claimed')
#
# Could not calculate ANOVA results
#
# Current pair:  2048 )  ('attacktype_txt', 'claim2')
# Insufficient data for analysis
# Current pair:  2049 )  ('attacktype_txt', 'claim3')
# Insufficient data for analysis
# Current pair:  2050 )  ('attacktype_txt', 'compclaim')
# Insufficient data for analysis
# Current pair:  2051 )  ('attacktype_txt', 'nkill')
#
# Could not calculate ANOVA results
#
# Current pair:  2052 )  ('attacktype_txt', 'nkillus')
#
# Could not calculate ANOVA results
#
# Current pair:  2053 )  ('attacktype_txt', 'nkillter')
#
# Could not calculate ANOVA results
#
# Current pair:  2054 )  ('attacktype_txt', 'nwound')
#
# Could not calculate ANOVA results
#
# Current pair:  2055 )  ('attacktype_txt', 'nwoundus')
#
# Could not calculate ANOVA results
#
# Current pair:  2056 )  ('attacktype_txt', 'nwoundte')
#
# Could not calculate ANOVA results
#
# Current pair:  2057 )  ('attacktype_txt', 'property')
#
# Could not calculate ANOVA results
#
# Current pair:  2058 )  ('attacktype_txt', 'propvalue')
# Insufficient data for analysis
# Current pair:  2059 )  ('attacktype_txt', 'ishostkid')
#
# Could not calculate ANOVA results
#
# Current pair:  2060 )  ('attacktype_txt', 'nhostkid')
# Insufficient data for analysis
# Current pair:  2061 )  ('attacktype_txt', 'nhostkidus')
# Insufficient data for analysis
# Current pair:  2062 )  ('attacktype_txt', 'nhours')
# Insufficient data for analysis
# Current pair:  2063 )  ('attacktype_txt', 'ndays')
# Insufficient data for analysis
# Current pair:  2064 )  ('attacktype_txt', 'ransom')
# Insufficient data for analysis
# Current pair:  2065 )  ('attacktype_txt', 'ransomamt')
# Insufficient data for analysis
# Current pair:  2066 )  ('attacktype_txt', 'ransomamtus')
# Insufficient data for analysis
# Current pair:  2067 )  ('attacktype_txt', 'ransompaid')
# Insufficient data for analysis
# Current pair:  2068 )  ('attacktype_txt', 'ransompaidus')
# Insufficient data for analysis
# Current pair:  2069 )  ('attacktype_txt', 'nreleased')
# Insufficient data for analysis

# %%
perform_anova_for_column(possible_pairs=column_pairs, data=data_for_analysis_new, column="attacktype_txt", treshold=0.4)
# Out:
# Total pairs:  2070
# Current pair:  44 )  ('eventid', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  89 )  ('iyear', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  134 )  ('imonth', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  179 )  ('iday', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  224 )  ('extended', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  269 )  ('latitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  314 )  ('longitude', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  359 )  ('specificity', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  404 )  ('vicinity', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  449 )  ('crit1', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  494 )  ('crit2', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  539 )  ('crit3', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  584 )  ('doubtterr', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  629 )  ('multiple', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  674 )  ('success', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  719 )  ('suicide', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  764 )  ('guncertain1', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  809 )  ('guncertain2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  854 )  ('guncertain3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  899 )  ('individual', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  944 )  ('nperps', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  989 )  ('nperpcap', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1034 )  ('claimed', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1079 )  ('claim2', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1124 )  ('claim3', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1169 )  ('compclaim', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1214 )  ('nkill', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1259 )  ('nkillus', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1304 )  ('nkillter', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1349 )  ('nwound', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1394 )  ('nwoundus', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1439 )  ('nwoundte', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1484 )  ('property', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1529 )  ('propvalue', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1574 )  ('ishostkid', 'attacktype_txt')
#
# The F-statistic and p-value are too low
#
# Current pair:  1619 )  ('nhostkid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1664 )  ('nhostkidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1709 )  ('nhours', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1754 )  ('ndays', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1799 )  ('ransom', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1844 )  ('ransomamt', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1889 )  ('ransomamtus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1934 )  ('ransompaid', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  1979 )  ('ransompaidus', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2024 )  ('nreleased', 'attacktype_txt')
# Insufficient data for analysis
# Current pair:  2025 )  ('attacktype_txt', 'eventid')
#
# Could not calculate ANOVA results
#
# Current pair:  2026 )  ('attacktype_txt', 'iyear')
#
# Could not calculate ANOVA results
#
# Current pair:  2027 )  ('attacktype_txt', 'imonth')
#
# Could not calculate ANOVA results
#
# Current pair:  2028 )  ('attacktype_txt', 'iday')
#
# Could not calculate ANOVA results
#
# Current pair:  2029 )  ('attacktype_txt', 'extended')
#
# Could not calculate ANOVA results
#
# Current pair:  2030 )  ('attacktype_txt', 'latitude')
#
# Could not calculate ANOVA results
#
# Current pair:  2031 )  ('attacktype_txt', 'longitude')
#
# Could not calculate ANOVA results
#
# Current pair:  2032 )  ('attacktype_txt', 'specificity')
#
# Could not calculate ANOVA results
#
# Current pair:  2033 )  ('attacktype_txt', 'vicinity')
#
# Could not calculate ANOVA results
#
# Current pair:  2034 )  ('attacktype_txt', 'crit1')
#
# Could not calculate ANOVA results
#
# Current pair:  2035 )  ('attacktype_txt', 'crit2')
#
# Could not calculate ANOVA results
#
# Current pair:  2036 )  ('attacktype_txt', 'crit3')
#
# Could not calculate ANOVA results
#
# Current pair:  2037 )  ('attacktype_txt', 'doubtterr')
#
# Could not calculate ANOVA results
#
# Current pair:  2038 )  ('attacktype_txt', 'multiple')
#
# Could not calculate ANOVA results
#
# Current pair:  2039 )  ('attacktype_txt', 'success')
#
# Could not calculate ANOVA results
#
# Current pair:  2040 )  ('attacktype_txt', 'suicide')
#
# Could not calculate ANOVA results
#
# Current pair:  2041 )  ('attacktype_txt', 'guncertain1')
#
# Could not calculate ANOVA results
#
# Current pair:  2042 )  ('attacktype_txt', 'guncertain2')
# Insufficient data for analysis
# Current pair:  2043 )  ('attacktype_txt', 'guncertain3')
# Insufficient data for analysis
# Current pair:  2044 )  ('attacktype_txt', 'individual')
#
# Could not calculate ANOVA results
#
# Current pair:  2045 )  ('attacktype_txt', 'nperps')
# Insufficient data for analysis
# Current pair:  2046 )  ('attacktype_txt', 'nperpcap')
#
# Could not calculate ANOVA results
#
# Current pair:  2047 )  ('attacktype_txt', 'claimed')
#
# Could not calculate ANOVA results
#
# Current pair:  2048 )  ('attacktype_txt', 'claim2')
# Insufficient data for analysis
# Current pair:  2049 )  ('attacktype_txt', 'claim3')
# Insufficient data for analysis
# Current pair:  2050 )  ('attacktype_txt', 'compclaim')
# Insufficient data for analysis
# Current pair:  2051 )  ('attacktype_txt', 'nkill')
#
# Could not calculate ANOVA results
#
# Current pair:  2052 )  ('attacktype_txt', 'nkillus')
#
# Could not calculate ANOVA results
#
# Current pair:  2053 )  ('attacktype_txt', 'nkillter')
#
# Could not calculate ANOVA results
#
# Current pair:  2054 )  ('attacktype_txt', 'nwound')
#
# Could not calculate ANOVA results
#
# Current pair:  2055 )  ('attacktype_txt', 'nwoundus')
#
# Could not calculate ANOVA results
#
# Current pair:  2056 )  ('attacktype_txt', 'nwoundte')
#
# Could not calculate ANOVA results
#
# Current pair:  2057 )  ('attacktype_txt', 'property')
#
# Could not calculate ANOVA results
#
# Current pair:  2058 )  ('attacktype_txt', 'propvalue')
# Insufficient data for analysis
# Current pair:  2059 )  ('attacktype_txt', 'ishostkid')
#
# Could not calculate ANOVA results
#
# Current pair:  2060 )  ('attacktype_txt', 'nhostkid')
# Insufficient data for analysis
# Current pair:  2061 )  ('attacktype_txt', 'nhostkidus')
# Insufficient data for analysis
# Current pair:  2062 )  ('attacktype_txt', 'nhours')
# Insufficient data for analysis
# Current pair:  2063 )  ('attacktype_txt', 'ndays')
# Insufficient data for analysis
# Current pair:  2064 )  ('attacktype_txt', 'ransom')
# Insufficient data for analysis
# Current pair:  2065 )  ('attacktype_txt', 'ransomamt')
# Insufficient data for analysis
# Current pair:  2066 )  ('attacktype_txt', 'ransomamtus')
# Insufficient data for analysis
# Current pair:  2067 )  ('attacktype_txt', 'ransompaid')
# Insufficient data for analysis
# Current pair:  2068 )  ('attacktype_txt', 'ransompaidus')
# Insufficient data for analysis
# Current pair:  2069 )  ('attacktype_txt', 'nreleased')
# Insufficient data for analysis

# %% [markdown]
# Could not find any correlation between attacktype and other values. Some of the calculations failes probably due to some workings of python which I fully do not understand. One possibility lies in fact that the data is not normally distributed which affects calculations.

# %% [markdown]
# # Identifying important correlations for the target nationalities

# %%
data = pd.read_csv("final_data.csv")
# Out:
# /home/achaad/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (5,24,25,44,45,46,57,59,67,68,83,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.natlty1_txt.describe()
# Out:
# count     180132
# unique       215
# top         Iraq
# freq       24113
# Name: natlty1_txt, dtype: object

# %%
data.natlty1_txt.value_counts()
# Out:
# Iraq                                  24113
# Pakistan                              13900
# India                                 12098
# Afghanistan                           10931
# Colombia                               7922
# Philippines                            6685
# Peru                                   5840
# El Salvador                            5212
# United States                          5065
# Turkey                                 4636
# Israel                                 4097
# Thailand                               3804
# Nigeria                                3759
# Northern Ireland                       3367
# Somalia                                3160
# Yemen                                  3123
# Spain                                  3096
# France                                 2918
# Sri Lanka                              2851
# International                          2699
# Algeria                                2664
# Egypt                                  2523
# Russia                                 2323
# Chile                                  2241
# Syria                                  2186
# Libya                                  2139
# Great Britain                          2131
# South Africa                           2062
# Nicaragua                              1960
# Guatemala                              1893
#                                       ...
# Belize                                    4
# Bermuda                                   3
# Dominica                                  3
# Virgin Islands (U.S.)                     3
# Gambia                                    3
# Martinique                                3
# Mongolia                                  2
# French Guiana                             2
# Brunei                                    2
# St. Martin                                2
# St. Kitts and Nevis                       2
# Mauritius                                 2
# Barbados                                  2
# Seychelles                                2
# Sinhalese                                 2
# Equatorial Guinea                         2
# Oman                                      2
# North Yemen                               2
# Vanuatu                                   2
# Turkmenistan                              2
# People's Republic of the Congo            1
# Greenland                                 1
# Western Sahara                            1
# Marshall Islands                          1
# Man, Isle of                              1
# Antigua and Barbuda                       1
# Tuvalu                                    1
# Commonwealth of Independent States        1
# St. Lucia                                 1
# Saba (Netherlands Antilles)               1
# Name: natlty1_txt, Length: 215, dtype: int64

# %% [markdown]
# ## Chi-square test

# %% [markdown]
# ### Before 1997

# %%
# Lists all categorical columns
cols = data.columns
num_cols = data._get_numeric_data().columns
cat_cols =  list(set(cols) - set(num_cols))
print(cat_cols)
# Out:
# ['corp3', 'provstate', 'hostkidoutcome_txt', 'gname3', 'corp2', 'attacktype3_txt', 'city', 'weapsubtype1_txt', 'gname', 'kidhijcountry', 'weaptype1_txt', 'corp1', 'weapsubtype2_txt', 'targtype1_txt', 'propextent_txt', 'weaptype3_txt', 'region_txt', 'related', 'claimmode3_txt', 'attacktype2_txt', 'weaptype2_txt', 'approxdate', 'targtype3_txt', 'natlty2_txt', 'gsubname2', 'natlty1_txt', 'weapsubtype4_txt', 'natlty3_txt', 'claimmode_txt', 'gname2', 'weapsubtype3_txt', 'targtype2_txt', 'country_txt', 'target1', 'motive', 'alternative_txt', 'gsubname3', 'targsubtype3_txt', 'gsubname', 'attacktype1_txt', 'weaptype4_txt', 'targsubtype2_txt', 'target3', 'targsubtype1_txt', 'claimmode2_txt', 'target2', 'divert']

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_old = data_old[cat_cols].copy(deep=True)
data_for_analysis_old.head()
# Out:
#   corp3 provstate hostkidoutcome_txt gname3 corp2 attacktype3_txt  \
# 0   NaN       NaN                NaN    NaN   NaN             NaN
# 1   NaN   Federal                NaN    NaN   NaN             NaN
# 2   NaN    Tarlac                NaN    NaN   NaN             NaN
# 3   NaN    Attica                NaN    NaN   NaN             NaN
# 4   NaN   Fukouka                NaN    NaN   NaN             NaN
#
#             city        weapsubtype1_txt                               gname  \
# 0  Santo Domingo                     NaN                              MANO-D
# 1    Mexico City                     NaN  23rd of September Communist League
# 2        Unknown                     NaN                             Unknown
# 3         Athens  Unknown Explosive Type                             Unknown
# 4        Fukouka                     NaN                             Unknown
#
#   kidhijcountry  ...   targsubtype3_txt gsubname  \
# 0           NaN  ...                NaN      NaN
# 1        Mexico  ...                NaN      NaN
# 2           NaN  ...                NaN      NaN
# 3           NaN  ...                NaN      NaN
# 4           NaN  ...                NaN      NaN
#
#                   attacktype1_txt weaptype4_txt targsubtype2_txt target3  \
# 0                   Assassination           NaN              NaN     NaN
# 1     Hostage Taking (Kidnapping)           NaN              NaN     NaN
# 2                   Assassination           NaN              NaN     NaN
# 3               Bombing/Explosion           NaN              NaN     NaN
# 4  Facility/Infrastructure Attack           NaN              NaN     NaN
#
#                                     targsubtype1_txt claimmode2_txt target2  \
# 0                                     Named Civilian            NaN     NaN
# 1  Diplomatic Personnel (outside of embassy, cons...            NaN     NaN
# 2                    Radio Journalist/Staff/Facility            NaN     NaN
# 3                                  Embassy/Consulate            NaN     NaN
# 4                                  Embassy/Consulate            NaN     NaN
#
#   divert
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#
# [5 rows x 47 columns]

# %%
# Finds all possible column pairs
cols = data_for_analysis_old.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('corp3', 'provstate'), ('corp3', 'hostkidoutcome_txt'), ('corp3', 'gname3'), ('corp3', 'corp2'), ('corp3', 'attacktype3_txt'), ('corp3', 'city'), ('corp3', 'weapsubtype1_txt'), ('corp3', 'gname'), ('corp3', 'kidhijcountry'), ('corp3', 'weaptype1_txt'), ('corp3', 'corp1'), ('corp3', 'weapsubtype2_txt'), ('corp3', 'targtype1_txt'), ('corp3', 'propextent_txt'), ('corp3', 'weaptype3_txt'), ('corp3', 'region_txt'), ('corp3', 'related'), ('corp3', 'claimmode3_txt'), ('corp3', 'attacktype2_txt'), ('corp3', 'weaptype2_txt'), ('corp3', 'approxdate'), ('corp3', 'targtype3_txt'), ('corp3', 'natlty2_txt'), ('corp3', 'gsubname2'), ('corp3', 'natlty1_txt'), ('corp3', 'weapsubtype4_txt'), ('corp3', 'natlty3_txt'), ('corp3', 'claimmode_txt'), ('corp3', 'gname2'), ('corp3', 'weapsubtype3_txt'), ('corp3', 'targtype2_txt'), ('corp3', 'country_txt'), ('corp3', 'target1'), ('corp3', 'motive'), ('corp3', 'alternative_txt'), ('corp3', 'gsubname3'), ('corp3', 'targsubtype3_txt'), ('corp3', 'gsubname'), ('corp3', 'attacktype1_txt'), ('corp3', 'weaptype4_txt'), ('corp3', 'targsubtype2_txt'), ('corp3', 'target3'), ('corp3', 'targsubtype1_txt'), ('corp3', 'claimmode2_txt'), ('corp3', 'target2'), ('corp3', 'divert'), ('provstate', 'corp3'), ('provstate', 'hostkidoutcome_txt'), ('provstate', 'gname3'), ('provstate', 'corp2'), ('provstate', 'attacktype3_txt'), ('provstate', 'city'), ('provstate', 'weapsubtype1_txt'), ('provstate', 'gname'), ('provstate', 'kidhijcountry'), ('provstate', 'weaptype1_txt'), ('provstate', 'corp1'), ('provstate', 'weapsubtype2_txt'), ('provstate', 'targtype1_txt'), ('provstate', 'propextent_txt'), ('provstate', 'weaptype3_txt'), ('provstate', 'region_txt'), ('provstate', 'related'), ('provstate', 'claimmode3_txt'), ('provstate', 'attacktype2_txt'), ('provstate', 'weaptype2_txt'), ('provstate', 'approxdate'), ('provstate', 'targtype3_txt'), ('provstate', 'natlty2_txt'), ('provstate', 'gsubname2'), ('provstate', 'natlty1_txt'), ('provstate', 'weapsubtype4_txt'), ('provstate', 'natlty3_txt'), ('provstate', 'claimmode_txt'), ('provstate', 'gname2'), ('provstate', 'weapsubtype3_txt'), ('provstate', 'targtype2_txt'), ('provstate', 'country_txt'), ('provstate', 'target1'), ('provstate', 'motive'), ('provstate', 'alternative_txt'), ('provstate', 'gsubname3'), ('provstate', 'targsubtype3_txt'), ('provstate', 'gsubname'), ('provstate', 'attacktype1_txt'), ('provstate', 'weaptype4_txt'), ('provstate', 'targsubtype2_txt'), ('provstate', 'target3'), ('provstate', 'targsubtype1_txt'), ('provstate', 'claimmode2_txt'), ('provstate', 'target2'), ('provstate', 'divert'), ('hostkidoutcome_txt', 'corp3'), ('hostkidoutcome_txt', 'provstate'), ('hostkidoutcome_txt', 'gname3'), ('hostkidoutcome_txt', 'corp2'), ('hostkidoutcome_txt', 'attacktype3_txt'), ('hostkidoutcome_txt', 'city'), ('hostkidoutcome_txt', 'weapsubtype1_txt'), ('hostkidoutcome_txt', 'gname'), ('hostkidoutcome_txt', 'kidhijcountry'), ('hostkidoutcome_txt', 'weaptype1_txt'), ('hostkidoutcome_txt', 'corp1'), ('hostkidoutcome_txt', 'weapsubtype2_txt'), ('hostkidoutcome_txt', 'targtype1_txt'), ('hostkidoutcome_txt', 'propextent_txt'), ('hostkidoutcome_txt', 'weaptype3_txt'), ('hostkidoutcome_txt', 'region_txt'), ('hostkidoutcome_txt', 'related'), ('hostkidoutcome_txt', 'claimmode3_txt'), ('hostkidoutcome_txt', 'attacktype2_txt'), ('hostkidoutcome_txt', 'weaptype2_txt'), ('hostkidoutcome_txt', 'approxdate'), ('hostkidoutcome_txt', 'targtype3_txt'), ('hostkidoutcome_txt', 'natlty2_txt'), ('hostkidoutcome_txt', 'gsubname2'), ('hostkidoutcome_txt', 'natlty1_txt'), ('hostkidoutcome_txt', 'weapsubtype4_txt'), ('hostkidoutcome_txt', 'natlty3_txt'), ('hostkidoutcome_txt', 'claimmode_txt'), ('hostkidoutcome_txt', 'gname2'), ('hostkidoutcome_txt', 'weapsubtype3_txt'), ('hostkidoutcome_txt', 'targtype2_txt'), ('hostkidoutcome_txt', 'country_txt'), ('hostkidoutcome_txt', 'target1'), ('hostkidoutcome_txt', 'motive'), ('hostkidoutcome_txt', 'alternative_txt'), ('hostkidoutcome_txt', 'gsubname3'), ('hos ...

# %%
calculate_chi_square_for_column(column_pairs, data_for_analysis_old, "natlty1_txt", 0.45)
# Out:
# Total pairs:  2162
# Current pair:  24 )  ('corp3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  70 )  ('provstate', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  116 )  ('hostkidoutcome_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  162 )  ('gname3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  208 )  ('corp2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  254 )  ('attacktype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  300 )  ('city', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  346 )  ('weapsubtype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  392 )  ('gname', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  438 )  ('kidhijcountry', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  484 )  ('weaptype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  530 )  ('corp1', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  576 )  ('weapsubtype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  622 )  ('targtype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  668 )  ('propextent_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  714 )  ('weaptype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  760 )  ('region_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  806 )  ('related', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  852 )  ('claimmode3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  898 )  ('attacktype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  944 )  ('weaptype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  990 )  ('approxdate', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1036 )  ('targtype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1082 )  ('natlty2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1128 )  ('gsubname2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1150 )  ('natlty1_txt', 'corp3')
# Insufficient data for analysis
# Current pair:  1151 )  ('natlty1_txt', 'provstate')
# Insufficient data for analysis
# Current pair:  1152 )  ('natlty1_txt', 'hostkidoutcome_txt')
# Insufficient data for analysis
# Current pair:  1153 )  ('natlty1_txt', 'gname3')
# Insufficient data for analysis
# Current pair:  1154 )  ('natlty1_txt', 'corp2')
# Insufficient data for analysis
# Current pair:  1155 )  ('natlty1_txt', 'attacktype3_txt')
# Insufficient data for analysis
# Current pair:  1156 )  ('natlty1_txt', 'city')
# Insufficient data for analysis
# Current pair:  1157 )  ('natlty1_txt', 'weapsubtype1_txt')
# Insufficient data for analysis
# Current pair:  1158 )  ('natlty1_txt', 'gname')
# Insufficient data for analysis
# Current pair:  1159 )  ('natlty1_txt', 'kidhijcountry')
# Insufficient data for analysis
# Current pair:  1160 )  ('natlty1_txt', 'weaptype1_txt')
# Insufficient data for analysis
# Current pair:  1161 )  ('natlty1_txt', 'corp1')
# Insufficient data for analysis
# Current pair:  1162 )  ('natlty1_txt', 'weapsubtype2_txt')
# Insufficient data for analysis
# Current pair:  1163 )  ('natlty1_txt', 'targtype1_txt')
# Insufficient data for analysis
# Current pair:  1164 )  ('natlty1_txt', 'propextent_txt')
# Insufficient data for analysis
# Current pair:  1165 )  ('natlty1_txt', 'weaptype3_txt')
# Insufficient data for analysis
# Current pair:  1166 )  ('natlty1_txt', 'region_txt')
# Insufficient data for analysis
# Current pair:  1167 )  ('natlty1_txt', 'related')
# Insufficient data for analysis
# Current pair:  1168 )  ('natlty1_txt', 'claimmode3_txt')
# Insufficient data for analysis
# Current pair:  1169 )  ('natlty1_txt', 'attacktype2_txt')
# Insufficient data for analysis
# Current pair:  1170 )  ('natlty1_txt', 'weaptype2_txt')
# Insufficient data for analysis
# Current pair:  1171 )  ('natlty1_txt', 'approxdate')
# Insufficient data for analysis
# Current pair:  1172 )  ('natlty1_txt', 'targtype3_txt')
# Insufficient data for analysis
# Current pair:  1173 )  ('natlty1_txt', 'natlty2_txt')
# Insufficient data for analysis
# Current pair:  1174 )  ('natlty1_txt', 'gsubname2')
# Insufficient data for analysis
# Current pair:  1175 )  ('natlty1_txt', 'weapsubtype4_txt')
# Insufficient data for analysis
# Current pair:  1176 )  ('natlty1_txt', 'natlty3_txt')
# Insufficient data for analysis
# Current pair:  1177 )  ('natlty1_txt', 'claimmode_txt')
# Insufficient data for analysis
# Current pair:  1178 )  ('natlty1_txt', 'gname2')
# Insufficient data for analysis
# Current pair:  1179 )  ('natlty1_txt', 'weapsubtype3_txt')
# Insufficient data for analysis
# Current pair:  1180 )  ('natlty1_txt', 'targtype2_txt')
# Insufficient data for analysis
# Current pair:  1181 )  ('natlty1_txt', 'country_txt')
# Insufficient data for analysis
# Current pair:  1182 )  ('natlty1_txt', 'target1')
# Insufficient data for analysis
# Current pair:  1183 )  ('natlty1_txt', 'motive')
# Insufficient data for analysis
# Current pair:  1184 )  ('natlty1_txt', 'alternative_txt')
# Insufficient data for analysis
# Current pair:  1185 )  ('natlty1_txt', 'gsubname3')
# Insufficient data for analysis
# Current pair:  1186 )  ('natlty1_txt', 'targsubtype3_txt')
# Insufficient data for analysis
# Current pair:  1187 )  ('natlty1_txt', 'gsubname')
# /home/achaad/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# Insufficient data for analysis
# Current pair:  1188 )  ('natlty1_txt', 'attacktype1_txt')
# Insufficient data for analysis
# Current pair:  1189 )  ('natlty1_txt', 'weaptype4_txt')
# Insufficient data for analysis
# Current pair:  1190 )  ('natlty1_txt', 'targsubtype2_txt')
# Insufficient data for analysis
# Current pair:  1191 )  ('natlty1_txt', 'target3')
# Insufficient data for analysis
# Current pair:  1192 )  ('natlty1_txt', 'targsubtype1_txt')
# Insufficient data for analysis
# Current pair:  1193 )  ('natlty1_txt', 'claimmode2_txt')
# Insufficient data for analysis
# Current pair:  1194 )  ('natlty1_txt', 'target2')
# Insufficient data for analysis
# Current pair:  1195 )  ('natlty1_txt', 'divert')
# Insufficient data for analysis
# Current pair:  1221 )  ('weapsubtype4_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1267 )  ('natlty3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1313 )  ('claimmode_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1359 )  ('gname2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1405 )  ('weapsubtype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1451 )  ('targtype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1497 )  ('country_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1543 )  ('target1', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1589 )  ('motive', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1635 )  ('alternative_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1681 )  ('gsubname3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1727 )  ('targsubtype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1773 )  ('gsubname', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1819 )  ('attacktype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1865 )  ('weaptype4_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1911 )  ('targsubtype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1957 )  ('target3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  2003 )  ('targsubtype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  2049 )  ('claimmode2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  2095 )  ('target2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  2141 )  ('divert', 'natlty1_txt')
# Insufficient data for analysis

# %% [markdown]
# Found no correlation

# %% [markdown]
# ### After 1997

# %%
# Creates a dataset containing only categorical columns
data_for_analysis_new = data_new[cat_cols].copy(deep=True)
data_for_analysis_new.head()
# Out:
#       corp3  provstate hostkidoutcome_txt gname3 corp2 attacktype3_txt  \
# 64310   NaN    Central                NaN    NaN   NaN             NaN
# 64311   NaN  West Bank                NaN    NaN   NaN             NaN
# 64312   NaN   Oklahoma                NaN    NaN   NaN             NaN
# 64313   NaN   Oklahoma                NaN    NaN   NaN             NaN
# 64314   NaN   Oklahoma                NaN    NaN   NaN             NaN
#
#          city                   weapsubtype1_txt                     gname  \
# 64310  Bethan                   Unknown Gun Type                   Unknown
# 64311  Hebron  Automatic or Semi-Automatic Rifle         Jewish Extremists
# 64312   Tulsa                                NaN  Anti-Abortion extremists
# 64313   Tulsa                                NaN  Anti-Abortion extremists
# 64314   Tulsa                                NaN  Anti-Abortion extremists
#
#       kidhijcountry  ...   targsubtype3_txt  gsubname  \
# 64310           NaN  ...                NaN       NaN
# 64311           NaN  ...                NaN  Settlers
# 64312           NaN  ...                NaN       NaN
# 64313           NaN  ...                NaN       NaN
# 64314           NaN  ...                NaN       NaN
#
#                       attacktype1_txt weaptype4_txt targsubtype2_txt target3  \
# 64310                   Armed Assault           NaN              NaN     NaN
# 64311                   Armed Assault           NaN              NaN     NaN
# 64312  Facility/Infrastructure Attack           NaN              NaN     NaN
# 64313  Facility/Infrastructure Attack           NaN              NaN     NaN
# 64314  Facility/Infrastructure Attack           NaN              NaN     NaN
#
#                                       targsubtype1_txt claimmode2_txt target2  \
# 64310  Police Building (headquarters, station, school)            NaN     NaN
# 64311                         Marketplace/Plaza/Square            NaN     NaN
# 64312                                          Clinics            NaN     NaN
# 64313                                          Clinics            NaN     NaN
# 64314                                          Clinics            NaN     NaN
#
#       divert
# 64310    NaN
# 64311    NaN
# 64312    NaN
# 64313    NaN
# 64314    NaN
#
# [5 rows x 47 columns]

# %%
# Finds all possible column pairs
cols = data_for_analysis_new.columns
column_pairs = find_pairs(cols)
print(column_pairs)
# Out:
# [('corp3', 'provstate'), ('corp3', 'hostkidoutcome_txt'), ('corp3', 'gname3'), ('corp3', 'corp2'), ('corp3', 'attacktype3_txt'), ('corp3', 'city'), ('corp3', 'weapsubtype1_txt'), ('corp3', 'gname'), ('corp3', 'kidhijcountry'), ('corp3', 'weaptype1_txt'), ('corp3', 'corp1'), ('corp3', 'weapsubtype2_txt'), ('corp3', 'targtype1_txt'), ('corp3', 'propextent_txt'), ('corp3', 'weaptype3_txt'), ('corp3', 'region_txt'), ('corp3', 'related'), ('corp3', 'claimmode3_txt'), ('corp3', 'attacktype2_txt'), ('corp3', 'weaptype2_txt'), ('corp3', 'approxdate'), ('corp3', 'targtype3_txt'), ('corp3', 'natlty2_txt'), ('corp3', 'gsubname2'), ('corp3', 'natlty1_txt'), ('corp3', 'weapsubtype4_txt'), ('corp3', 'natlty3_txt'), ('corp3', 'claimmode_txt'), ('corp3', 'gname2'), ('corp3', 'weapsubtype3_txt'), ('corp3', 'targtype2_txt'), ('corp3', 'country_txt'), ('corp3', 'target1'), ('corp3', 'motive'), ('corp3', 'alternative_txt'), ('corp3', 'gsubname3'), ('corp3', 'targsubtype3_txt'), ('corp3', 'gsubname'), ('corp3', 'attacktype1_txt'), ('corp3', 'weaptype4_txt'), ('corp3', 'targsubtype2_txt'), ('corp3', 'target3'), ('corp3', 'targsubtype1_txt'), ('corp3', 'claimmode2_txt'), ('corp3', 'target2'), ('corp3', 'divert'), ('provstate', 'corp3'), ('provstate', 'hostkidoutcome_txt'), ('provstate', 'gname3'), ('provstate', 'corp2'), ('provstate', 'attacktype3_txt'), ('provstate', 'city'), ('provstate', 'weapsubtype1_txt'), ('provstate', 'gname'), ('provstate', 'kidhijcountry'), ('provstate', 'weaptype1_txt'), ('provstate', 'corp1'), ('provstate', 'weapsubtype2_txt'), ('provstate', 'targtype1_txt'), ('provstate', 'propextent_txt'), ('provstate', 'weaptype3_txt'), ('provstate', 'region_txt'), ('provstate', 'related'), ('provstate', 'claimmode3_txt'), ('provstate', 'attacktype2_txt'), ('provstate', 'weaptype2_txt'), ('provstate', 'approxdate'), ('provstate', 'targtype3_txt'), ('provstate', 'natlty2_txt'), ('provstate', 'gsubname2'), ('provstate', 'natlty1_txt'), ('provstate', 'weapsubtype4_txt'), ('provstate', 'natlty3_txt'), ('provstate', 'claimmode_txt'), ('provstate', 'gname2'), ('provstate', 'weapsubtype3_txt'), ('provstate', 'targtype2_txt'), ('provstate', 'country_txt'), ('provstate', 'target1'), ('provstate', 'motive'), ('provstate', 'alternative_txt'), ('provstate', 'gsubname3'), ('provstate', 'targsubtype3_txt'), ('provstate', 'gsubname'), ('provstate', 'attacktype1_txt'), ('provstate', 'weaptype4_txt'), ('provstate', 'targsubtype2_txt'), ('provstate', 'target3'), ('provstate', 'targsubtype1_txt'), ('provstate', 'claimmode2_txt'), ('provstate', 'target2'), ('provstate', 'divert'), ('hostkidoutcome_txt', 'corp3'), ('hostkidoutcome_txt', 'provstate'), ('hostkidoutcome_txt', 'gname3'), ('hostkidoutcome_txt', 'corp2'), ('hostkidoutcome_txt', 'attacktype3_txt'), ('hostkidoutcome_txt', 'city'), ('hostkidoutcome_txt', 'weapsubtype1_txt'), ('hostkidoutcome_txt', 'gname'), ('hostkidoutcome_txt', 'kidhijcountry'), ('hostkidoutcome_txt', 'weaptype1_txt'), ('hostkidoutcome_txt', 'corp1'), ('hostkidoutcome_txt', 'weapsubtype2_txt'), ('hostkidoutcome_txt', 'targtype1_txt'), ('hostkidoutcome_txt', 'propextent_txt'), ('hostkidoutcome_txt', 'weaptype3_txt'), ('hostkidoutcome_txt', 'region_txt'), ('hostkidoutcome_txt', 'related'), ('hostkidoutcome_txt', 'claimmode3_txt'), ('hostkidoutcome_txt', 'attacktype2_txt'), ('hostkidoutcome_txt', 'weaptype2_txt'), ('hostkidoutcome_txt', 'approxdate'), ('hostkidoutcome_txt', 'targtype3_txt'), ('hostkidoutcome_txt', 'natlty2_txt'), ('hostkidoutcome_txt', 'gsubname2'), ('hostkidoutcome_txt', 'natlty1_txt'), ('hostkidoutcome_txt', 'weapsubtype4_txt'), ('hostkidoutcome_txt', 'natlty3_txt'), ('hostkidoutcome_txt', 'claimmode_txt'), ('hostkidoutcome_txt', 'gname2'), ('hostkidoutcome_txt', 'weapsubtype3_txt'), ('hostkidoutcome_txt', 'targtype2_txt'), ('hostkidoutcome_txt', 'country_txt'), ('hostkidoutcome_txt', 'target1'), ('hostkidoutcome_txt', 'motive'), ('hostkidoutcome_txt', 'alternative_txt'), ('hostkidoutcome_txt', 'gsubname3'), ('hos ...

# %%
calculate_chi_square_for_column(column_pairs, data_for_analysis_new, "natlty1_txt", 0.45)
# Out:
# Total pairs:  2162
# Current pair:  24 )  ('corp3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  70 )  ('provstate', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  116 )  ('hostkidoutcome_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  162 )  ('gname3', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  208 )  ('corp2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  254 )  ('attacktype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  300 )  ('city', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  346 )  ('weapsubtype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  392 )  ('gname', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  438 )  ('kidhijcountry', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  484 )  ('weaptype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  530 )  ('corp1', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  576 )  ('weapsubtype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  622 )  ('targtype1_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  668 )  ('propextent_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  714 )  ('weaptype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  760 )  ('region_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  806 )  ('related', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  852 )  ('claimmode3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  898 )  ('attacktype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  944 )  ('weaptype2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  990 )  ('approxdate', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1036 )  ('targtype3_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1082 )  ('natlty2_txt', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1128 )  ('gsubname2', 'natlty1_txt')
# Insufficient data for analysis
# Current pair:  1150 )  ('natlty1_txt', 'corp3')
# Insufficient data for analysis
# Current pair:  1151 )  ('natlty1_txt', 'provstate')
